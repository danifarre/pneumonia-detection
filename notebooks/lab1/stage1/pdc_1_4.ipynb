# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 15477
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 190,608
# Trainable params: 190,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,321,041
# Trainable params: 2,321,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
history = model.fit(x=x_train,
                    y=y_train,
                    validation_data=(x_val, y_val),
                    epochs=35)
# Out:
# Epoch 1/35
# 626/626 [==============================] - 31s 37ms/step - loss: 0.5026 - binary_accuracy: 0.7727 - precision: 0.4866 - recall: 0.0678 - val_loss: 0.4261 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000
# Epoch 2/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.4370 - binary_accuracy: 0.7990 - precision: 0.6026 - recall: 0.3085 - val_loss: 0.3382 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000: 9s - loss: 0.4370 - binary_acc - ETA: 0s - loss: 0.4370 - binary_accuracy: 0.7990 - precision: 0.6025 - recall: 0.30
# Epoch 3/35
# 626/626 [==============================] - 20s 31ms/step - loss: 0.4273 - binary_accuracy: 0.8052 - precision: 0.6230 - recall: 0.3149 - val_loss: 0.2847 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 4/35
# 626/626 [==============================] - 20s 31ms/step - loss: 0.4222 - binary_accuracy: 0.8103 - precision: 0.6239 - recall: 0.3906 - val_loss: 0.3393 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.500020 - binary_accur - ETA: 12s - loss: 0.4258 - ETA: 0s - loss: 0.4222 - binary_accuracy: 0.8104 - precision:
# Epoch 5/35
# 626/626 [==============================] - 20s 31ms/step - loss: 0.4160 - binary_accuracy: 0.8097 - precision: 0.6300 - recall: 0.3715 - val_loss: 0.3021 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 6/35
# 626/626 [==============================] - 20s 31ms/step - loss: 0.4106 - binary_accuracy: 0.8115 - precision: 0.6410 - recall: 0.4085 - val_loss: 0.2839 - val_binary_accuracy: 0.8500 - val_precision: 1.0000 - val_recall: 0.2500
# Epoch 7/35
# 626/626 [==============================] - 20s 31ms/step - loss: 0.4072 - binary_accuracy: 0.8152 - precision: 0.6538 - recall: 0.3940 - val_loss: 0.2566 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7
- val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500ecall: 0. - ETA: 12s - loss: 0.1065 - binary_accuracy: 0.9593 - precision: 0.9184 - - ETA: 12s - loss: 0.1063 - binary_accuracy: 0.9592 - precision: 0.9180 - recall: 0. - ETA: 11s - loss: 0.1063 - binary_a - ETA: 9s - loss: 0.1060 - binary_accuracy: - ETA: 7s - loss: 0.1059 - binary_accuracy: 0 - ETA: 6s - loss: 0 - E - ETA: 1s - loss: 0.1071 - binary_accuracy: 0.9 - ETA: 0s - loss: 0.1074 - binary_accuracy: 0.9582 - precision: 0.9158 - re
# Epoch 32/35
# 626/626 [==============================] - 20s 32ms/step - loss: 0.1030 - binary_accuracy: 0.9620 - precision: 0.9280 - recall: 0.9056 - val_loss: 0.0189 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000026 - binary_accuracy: 0.9622 - precision: 0.9285 - recall:  - ETA: 1s - loss: 0.1026 - binary_accuracy: 0.9622
# Epoch 33/35
# 626/626 [==============================] - 20s 32ms/step - loss: 0.0959 - binary_accuracy: 0.9642 - precision: 0.9287 - recall: 0.9126 - val_loss: 0.0736 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 34/35
# 626/626 [==============================] - 20s 32ms/step - loss: 0.1015 - binary_accuracy: 0.9599 - precision: 0.9162 - recall: 0.9065 - val_loss: 0.0517 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500 - loss: 0.1012 - binary_accuracy: 0.9
# Epoch 35/35
# 626/626 [==============================] - 20s 32ms/step - loss: 0.0869 - binary_accuracy: 0.9661 - precision: 0.9338 - recall: 0.9125 - val_loss: 0.0147 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000844 - binary_accuracy: 0.9668 -  - ETA: 3s - loss: 0.0851 - binary_accuracy: 0.9666 - precision: 0

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 16ms/step - loss: 2.4444 - binary_accuracy: 0.6711 - precision: 0.8128 - recall: 0.4207

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 142.97it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 126.40it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 126.76it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 129.71it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 125.02it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 125.75it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 127.77it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 128.85it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 126.28it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 151.00it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
