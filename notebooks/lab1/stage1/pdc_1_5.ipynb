# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 15477
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 99,760
# Trainable params: 99,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,230,193
# Trainable params: 2,230,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
history = model.fit(x=x_train,
                    y=y_train,
                    validation_data=(x_val, y_val),
                    epochs=35)
# Out:
# Epoch 1/35
# 626/626 [==============================] - 25s 29ms/step - loss: 0.4938 - binary_accuracy: 0.7685 - precision: 0.4791 - recall: 0.0486 - val_loss: 0.3502 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.4357 - binary_accuracy: 0.7972 - precision: 0.5954 - recall: 0.3382 - val_loss: 0.3070 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 3/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.4291 - binary_accuracy: 0.8047 - precision: 0.6168 - recall: 0.3631 - val_loss: 0.3166 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 4/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.4195 - binary_accuracy: 0.8083 - precision: 0.6252 - recall: 0.3850 - val_loss: 0.2801 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000acy: 0.8 - ETA: 1s - loss: 0.4189 - binary_accuracy: 0.8083 - precision: 0.6255 - recall - ETA: 1s - loss: 0.4189 - binary_accuracy: 0.8083 - precision: 0.6254 - recall: 0. - ETA: 1s - loss: 0.4190 - binary_accuracy:
# Epoch 5/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.4201 - binary_accuracy: 0.8095 - precision: 0.6325 - recall: 0.4203 - val_loss: 0.3325 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 6/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.4099 - binary_accuracy: 0.8144 - precision: 0.6390 - recall: 0.4199 - val_loss: 0.2331 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 7/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.4079 - binary_accuracy: 0.8122 - precision: 0.6292 - recall: 0.4051 - val_loss: 0.2392 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 8/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0
- val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000- precis - ETA: 3s - loss: 0.1836 - binary_accuracy: 0.9238 - precision: 0.8610 - recall:  - ETA: 3s - loss: 0.1838 - binary_accuracy: 0.9237 - precision: 0.8609 -  - ETA: 2s - loss: - ETA: 0s - loss: 0.1856 - binary_accuracy: 0.9230 - precision: 0.8597 -
# Epoch 28/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1770 - binary_accuracy: 0.9271 - precision: 0.8649 - recall: 0.8056 - val_loss: 0.0838 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 29/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1761 - binary_accuracy: 0.9292 - precision: 0.8671 - recall: 0.8172 - val_loss: 0.0599 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - precis - ETA: 8s -
# Epoch 30/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1562 - binary_accuracy: 0.9394 - precision: 0.8921 - recall: 0.8337 - val_loss: 0.0248 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.00009419 - precision: 0.896
# Epoch 31/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1418 - binary_accuracy: 0.9441 - precision: 0.8956 - recall: 0.8535 - val_loss: 0.0253 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000accuracy: 0 - ETA: 8s - l - ETA: 0s - loss: 0.1417 - binary_accuracy: 0.9442 - precision: 0.8957 - recall:
# Epoch 32/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1568 - binary_accuracy: 0.9372 - precision: 0.8918 - recall: 0.8203 - val_loss: 0.0163 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1405 - binary_accuracy: 0.9439 - precision: 0.8927 - recall: 0.8533 - val_loss: 0.0432 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000prec
# Epoch 34/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1251 - binary_accuracy: 0.9508 - precision: 0.9004 - recall: 0.8754 - val_loss: 0.0164 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/35
# 626/626 [==============================] - 15s 24ms/step - loss: 0.1235 - binary_accuracy: 0.9528 - precision: 0.9114 - recall: 0.8782 - val_loss: 0.0216 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000.1181 - binary_accur

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 16ms/step - loss: 1.3703 - binary_accuracy: 0.6777 - precision: 0.7978 - recall: 0.4519

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 140.13it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 117.85it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 118.71it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 120.17it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 118.63it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 117.34it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 120.36it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.15it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 118.82it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 129.83it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
