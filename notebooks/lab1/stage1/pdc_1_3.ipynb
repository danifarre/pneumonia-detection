# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 15477
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# =================================================================
# Total params: 25,904
# Trainable params: 25,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4194560
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 4,253,489
# Trainable params: 4,253,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
history = model.fit(x=x_train,
                    y=y_train,
                    validation_data=(x_val, y_val),
                    epochs=35)
# Out:
# Epoch 1/35
# 626/626 [==============================] - 26s 30ms/step - loss: 0.5011 - binary_accuracy: 0.7732 - precision: 0.4842 - recall: 0.0814 - val_loss: 0.3178 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000
# Epoch 2/35
# 626/626 [==============================] - 16s 25ms/step - loss: 0.4490 - binary_accuracy: 0.7892 - precision: 0.5749 - recall: 0.2425 - val_loss: 0.3420 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000y: 0.7892 - precisio
# Epoch 3/35
# 626/626 [==============================] - 16s 25ms/step - loss: 0.4361 - binary_accuracy: 0.7960 - precision: 0.5990 - recall: 0.2814 - val_loss: 0.2823 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 4/35
# 626/626 [==============================] - 16s 25ms/step - loss: 0.4329 - binary_accuracy: 0.8011 - precision: 0.6203 - recall: 0.3546 - val_loss: 0.2747 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 5/35
# 626/626 [==============================] - 16s 25ms/step - loss: 0.4185 - binary_accuracy: 0.8114 - precision: 0.6488 - recall: 0.3681 - val_loss: 0.3053 - val_binary_accuracy: 0.9000 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 6/35
# 626/626 [==============================] - 16s 26ms/step - loss: 0.4060 - binary_accuracy: 0.8207 - precision: 0.6655 - recall: 0.4075 - val_loss: 0.2105 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 7/35
# 626/626 [==============================] - 16s 26ms/step - loss: 0.4056 - binary_accuracy: 0.8156 - precision: 0.6496 - recall: 0.4163 - val_loss: 0.2390 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7
- val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 29/35
# 626/626 [==============================] - 17s 26ms/step - loss: 0.1007 - binary_accuracy: 0.9613 - precision: 0.9242 - recall: 0.9018 - val_loss: 0.0047 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/35
# 626/626 [==============================] - 17s 26ms/step - loss: 0.1022 - binary_accuracy: 0.9577 - precision: 0.9134 - recall: 0.8978 - val_loss: 0.0080 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 loss: 0.1052 - binary_accuracy: 0.9514 - prec - ETA: 12s - loss: 0.1017 - bi
# Epoch 31/35
# 626/626 [==============================] - 17s 26ms/step - loss: 0.0952 - binary_accuracy: 0.9637 - precision: 0.9278 - recall: 0.9101 - val_loss: 0.0073 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 32/35
# 626/626 [==============================] - 17s 26ms/step - loss: 0.0896 - binary_accuracy: 0.9648 - precision: 0.9348 - recall: 0.9101 - val_loss: 0.0022 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/35
# 626/626 [==============================] - 16s 26ms/step - loss: 0.0881 - binary_accuracy: 0.9661 - precision: 0.9287 - recall: 0.9238 - val_loss: 0.0107 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 34/35
# 626/626 [==============================] - 17s 26ms/step - loss: 0.0869 - binary_accuracy: 0.9644 - precision: 0.9213 - recall: 0.9226 - val_loss: 0.0025 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/35
# 626/626 [==============================] - 16s 26ms/step - loss: 0.0812 - binary_accuracy: 0.9685 - precision: 0.9335 - recall: 0.9250 - val_loss: 0.0070 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 17ms/step - loss: 1.8448 - binary_accuracy: 0.6691 - precision: 0.8260 - recall: 0.4051

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:08<00:00, 123.93it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.16it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.75it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 123.26it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.69it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.29it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 120.61it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 119.55it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 119.38it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 124.13it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
