# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 15477
#  - Pneumonia: 4536
# Test:
#  - Normal: 5195
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# =================================================================
# Total params: 6,032
# Trainable params: 6,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,427,921
# Trainable params: 8,427,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
history = model.fit(x=x_train,
                    y=y_train,
                    validation_data=(x_val, y_val),
                    epochs=35)
# Out:
# Epoch 1/35
# 626/626 [==============================] - 30s 35ms/step - loss: 0.5685 - binary_accuracy: 0.7680 - precision: 0.4470 - recall: 0.0693 - val_loss: 0.3341 - val_binary_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4557 - binary_accuracy: 0.7847 - precision: 0.5580 - recall: 0.2282 - val_loss: 0.3201 - val_binary_accuracy: 0.9000 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 3/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4350 - binary_accuracy: 0.8020 - precision: 0.6166 - recall: 0.2940 - val_loss: 0.3138 - val_binary_accuracy: 0.8500 - val_precision: 1.0000 - val_recall: 0.2500
# Epoch 4/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4168 - binary_accuracy: 0.8086 - precision: 0.6254 - recall: 0.3463 - val_loss: 0.2898 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000
# Epoch 5/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4124 - binary_accuracy: 0.8146 - precision: 0.6654 - recall: 0.4009 - val_loss: 0.2326 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 6/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0
- val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 27/35
# 626/626 [==============================] - 18s 29ms/step - loss: 0.0624 - binary_accuracy: 0.9761 - precision: 0.9485 - recall: 0.9458 - val_loss: 0.0037 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 28/35
# 626/626 [==============================] - 18s 29ms/step - loss: 0.0579 - binary_accuracy: 0.9781 - precision: 0.9517 - recall: 0.9513 - val_loss: 0.0095 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 29/35
# 626/626 [==============================] - 18s 29ms/step - loss: 0.0555 - binary_accuracy: 0.9782 - precision: 0.9567 - recall: 0.9466 - val_loss: 0.0034 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/35
# 626/626 [==============================] - 18s 30ms/step - loss: 0.0580 - binary_accuracy: 0.9791 - precision: 0.9554 - recall: 0.9517 - val_loss: 0.0026 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 31/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0623 - binary_accuracy: 0.9794 - precision: 0.9589 - recall: 0.9495 - val_loss: 0.0011 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 32/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0506 - binary_accuracy: 0.9815 - precision: 0.9558 - recall: 0.9622 - val_loss: 0.0012 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0555 - binary_accuracy: 0.9805 - precision: 0.9589 - recall: 0.9528 - val_loss: 0.0011 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 34/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0556 - binary_accuracy: 0.9793 - precision: 0.9563 - recall: 0.9526 - val_loss: 0.0021 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0502 - binary_accuracy: 0.9827 - precision: 0.9636 - recall: 0.9585 - val_loss: 5.4053e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 209/209 [==============================] - 4s 15ms/step - loss: 1.2927 - binary_accuracy: 0.7840 - precision: 0.5156 - recall: 0.3930

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 145.68it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 142.80it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 148.39it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 147.41it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 146.36it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 148.68it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 141.75it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 146.79it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 153.69it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 142.11it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
