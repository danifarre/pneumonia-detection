# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 15477
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# =================================================================
# Total params: 6,032
# Trainable params: 6,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,427,921
# Trainable params: 8,427,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
history = model.fit(x=x_train,
                    y=y_train,
                    validation_data=(x_val, y_val),
                    epochs=35)
# Out:
# Epoch 1/35
# 626/626 [==============================] - 29s 34ms/step - loss: 0.4932 - binary_accuracy: 0.7689 - precision: 0.4430 - recall: 0.0962 - val_loss: 0.3249 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/35
# 626/626 [==============================] - 18s 29ms/step - loss: 0.4488 - binary_accuracy: 0.7929 - precision: 0.6049 - recall: 0.2672 - val_loss: 0.3423 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 3/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4378 - binary_accuracy: 0.7987 - precision: 0.6145 - recall: 0.3045 - val_loss: 0.2879 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.50003 - binary - ETA: 1s - loss: 0.4380 - binary_accuracy: 0.7
# Epoch 4/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4203 - binary_accuracy: 0.8074 - precision: 0.6433 - recall: 0.3616 - val_loss: 0.2720 - val_binary_accuracy: 0.9000 - val_precision: 0.7500 - val_recall: 0.7500_accuracy: 0.8 - ETA: 1s - loss: 0.4201 - binary_accuracy: 0.807
# Epoch 5/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4019 - binary_accuracy: 0.8218 - precision: 0.6663 - recall: 0.4147 - val_loss: 0.2403 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 6/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.3772 - binary_accuracy: 0.8348 - precision: 0.7093 - recall: 0.4624 - val_loss: 0.2338 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000
# Epoch 7/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.3371 - binary_accuracy: 0.8577 - precision: 0.7594 - recall: 0.5308 - val_loss: 0.2247 - val_binary_accuracy: 0.9000 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 8/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.3015 - binary_accuracy: 0.8768 - precision: 0.7932 - recall: 0.5986 - val_loss: 0.1637 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 9/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0
35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0602 - binary_accuracy: 0.9777 - precision: 0.9530 - recall: 0.9463 - val_loss: 0.0112 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 23/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0638 - binary_accuracy: 0.9785 - precision: 0.9598 - recall: 0.9453 - val_loss: 0.0215 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 24/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0549 - binary_accuracy: 0.9823 - precision: 0.9681 - recall: 0.9532 - val_loss: 0.0029 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 25/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0553 - binary_accuracy: 0.9802 - precision: 0.9618 - recall: 0.9508 - val_loss: 0.0016 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 26/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0504 - binary_accuracy: 0.9826 - precision: 0.9643 - recall: 0.9571 - val_loss: 0.0013 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 27/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0476 - binary_accuracy: 0.9838 - precision: 0.9699 - recall: 0.9591 - val_loss: 0.0048 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - binary_accuracy: 0.9839 - precision: 0.9708 - recall: 0. - ETA: 4s - loss: 0 - ETA
# Epoch 28/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0529 - binary_accuracy: 0.9801 - precision: 0.9596 - recall: 0.9521 - val_loss: 0.0014 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000recision: 0.9554 - - ETA
# Epoch 29/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0431 - binary_accuracy: 0.9852 - precision: 0.9712 - recall: 0.9645 - val_loss: 0.0049 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0400 - binary_accuracy: 0.9868 - precision: 0.9704 - recall: 0.9715 - val_loss: 0.0032 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 31/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0514 - binary_accuracy: 0.9817 - precision: 0.9638 - recall: 0.9556 - val_loss: 9.4261e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 32/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0413 - binary_accuracy: 0.9860 - precision: 0.9711 - recall: 0.9664 - val_loss: 0.0013 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0389 - binary_accuracy: 0.9871 - precision: 0.9756 - recall: 0.9669 - val_loss: 3.1220e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000- loss: 0.0405 - binary_accuracy - ETA: 9s - loss: 0.0395 - binary_accuracy: 0.9867 - precisio - ETA: 9s - loss: 0.0393 - binary_accuracy: 0.9868 - precis
# Epoch 34/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0425 - binary_accuracy: 0.9851 - precision: 0.9735 - recall: 0.9616 - val_loss: 5.0289e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0409 - binary_accuracy: 0.9854 - precision: 0.9701 - recall: 0.9663 - val_loss: 0.0015 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 1s 14ms/step - loss: 2.8539 - binary_accuracy: 0.6421 - precision: 0.8095 - recall: 0.3455

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 130.27it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 146.36it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 148.59it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 148.07it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 144.83it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 145.04it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 146.19it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 146.32it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 144.87it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 142.69it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
