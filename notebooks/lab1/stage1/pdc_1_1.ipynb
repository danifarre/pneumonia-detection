# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 15477
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# =================================================================
# Total params: 6,032
# Trainable params: 6,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,427,921
# Trainable params: 8,427,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
history = model.fit(x=x_train,
                    y=y_train,
                    validation_data=(x_val, y_val),
                    epochs=35)
# Out:
# Epoch 1/35
# 626/626 [==============================] - 38s 34ms/step - loss: 0.5008 - binary_accuracy: 0.7689 - precision: 0.4870 - recall: 0.1086 - val_loss: 0.3958 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 2/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4454 - binary_accuracy: 0.7968 - precision: 0.6060 - recall: 0.2732 - val_loss: 0.3451 - val_binary_accuracy: 0.9000 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 3/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4240 - binary_accuracy: 0.8089 - precision: 0.6408 - recall: 0.3419 - val_loss: 0.2653 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000- recall: 0.
# Epoch 4/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.4146 - binary_accuracy: 0.8100 - precision: 0.6588 - recall: 0.3641 - val_loss: 0.3252 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 5/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.3858 - binary_accuracy: 0.8309 - precision: 0.7047 - recall: 0.4042 - val_loss: 0.2193 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.75007 - binary_accuracy: 0.8310 - precision: 0.7049 - recall
# Epoch 6/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.3609 - binary_accuracy: 0.8396 - precision: 0.7224 - recall: 0.4821 - val_loss: 0.1735 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 7/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.3185 - binary_accuracy: 0.8674 - precision: 0.7788 - recall: 0.6012 - val_loss: 0.1249 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 8/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.2708 - binary_accuracy: 0.8856 - precision: 0.8157 - recall: 0.6430 - val_loss: 0.1034 - val_binary_accuracy: 0.9500 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 9/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.2370 - binary_accuracy: 0.9035 - precision: 0.8466 - recall: 0.6924 - val_loss: 0.0745 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000396 - binary_accuracy: 0.9036 -  - ETA: 14s - loss: 0.2357 - binary_accuracy: 0.9069 - precision: 0.8679 - recall: 0.667  - ETA: 7s - loss: 0.237
# Epoch 10/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0
- val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000ry_accuracy: 0.9848 - precision: 0.9701 - reca
# Epoch 26/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0433 - binary_accuracy: 0.9848 - precision: 0.9703 - recall: 0.9618 - val_loss: 0.0012 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000uracy: 0.9880 - precision: 0.9808 - ETA: 12s - ETA: 0s - loss: 0.0431 - binary_accuracy: 0.9849 - pr
# Epoch 27/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0410 - binary_accuracy: 0.9854 - precision: 0.9724 - recall: 0.9629 - val_loss: 0.0010 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 28/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0455 - binary_accuracy: 0.9838 - precision: 0.9666 - recall: 0.9614 - val_loss: 0.0022 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 29/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0411 - binary_accuracy: 0.9854 - precision: 0.9714 - recall: 0.9642 - val_loss: 0.0036 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0375 - binary_accuracy: 0.9860 - precision: 0.9710 - recall: 0.9669 - val_loss: 0.0010 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - loss: 0.0 - ETA: 1s - loss: 0.0376 - binary
# Epoch 31/35
# 626/626 [==============================] - 19s 30ms/step - loss: 0.0383 - binary_accuracy: 0.9860 - precision: 0.9701 - recall: 0.9673 - val_loss: 0.0012 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 32/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0332 - binary_accuracy: 0.9884 - precision: 0.9776 - recall: 0.9711 - val_loss: 0.0021 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0351 - binary_accuracy: 0.9877 - precision: 0.9745 - recall: 0.9696 - val_loss: 6.5925e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.00009749 - recall: 0. - ETA: 2s - loss: 0.0346 - binary - ETA: 1s - loss: 0.0349 - binary_accuracy: 0.9878
# Epoch 34/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0345 - binary_accuracy: 0.9884 - precision: 0.9754 - recall: 0.9743 - val_loss: 3.7094e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 0.9888 - precision: 0.9763 - reca - ETA: 4s - los
# Epoch 35/35
# 626/626 [==============================] - 19s 31ms/step - loss: 0.0369 - binary_accuracy: 0.9860 - precision: 0.9684 - recall: 0.9697 - val_loss: 1.1619e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - precision: 0. - ETA: 11s - loss: 0.0365 - binary_accuracy: 0.9856 - precision: 0.9666  - ETA: 10s - loss: 0.0367 - bina - ETA: 6s - loss: 0.0372 - binary_accurac - ETA: 4s - loss: 0.037

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 1s 13ms/step - loss: 2.7669 - binary_accuracy: 0.6655 - precision: 0.7794 - recall: 0.4356

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 149.59it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 143.35it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 138.84it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 155.29it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 163.38it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 150.24it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 156.47it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 147.84it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 145.78it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 152.81it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
