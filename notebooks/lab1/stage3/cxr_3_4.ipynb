# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 190,608
# Trainable params: 190,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,321,041
# Trainable params: 2,321,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 32s 145ms/step - loss: 0.6383 - binary_accuracy: 0.6067 - precision: 0.6276 - recall: 0.8192 - val_loss: 0.6050 - val_binary_accuracy: 0.5625 - val_precision: 0.5455 - val_recall: 0.7500
# Epoch 2/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.4438 - binary_accuracy: 0.8142 - precision: 0.8624 - recall: 0.8107 - val_loss: 0.5411 - val_binary_accuracy: 0.7500 - val_precision: 0.8333 - val_recall: 0.6250
# Epoch 3/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.4204 - binary_accuracy: 0.8203 - precision: 0.8796 - recall: 0.8025 - val_loss: 0.5308 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 4/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.3927 - binary_accuracy: 0.8421 - precision: 0.8934 - recall: 0.8254 - val_loss: 0.4450 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 5/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3930 - binary_accuracy: 0.8481 - precision: 0.9094 - recall: 0.8237 - val_loss: 0.4922 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 6/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.3643 - binary_accuracy: 0.8480 - precision: 0.9202 - recall: 0.8224 - val_loss: 0.6555 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 7/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.3432 - binary_accuracy: 0.8683 - precision: 0.9152 - recall: 0.8550 - val_loss: 0.4098 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch
- val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 26/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2157 - binary_accuracy: 0.9213 - precision: 0.9445 - recall: 0.9188 - val_loss: 0.4648 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 27/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.2282 - binary_accuracy: 0.9161 - precision: 0.9470 - recall: 0.9130 - val_loss: 0.6544 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 28/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.2215 - binary_accuracy: 0.9174 - precision: 0.9451 - recall: 0.9122 - val_loss: 0.5185 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 29/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.2238 - binary_accuracy: 0.9171 - precision: 0.9443 - recall: 0.9120 - val_loss: 0.5192 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 30/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2098 - binary_accuracy: 0.9242 - precision: 0.9531 - recall: 0.9168 - val_loss: 0.4529 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 31/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2449 - binary_accuracy: 0.9163 - precision: 0.9397 - recall: 0.9161 - val_loss: 0.4955 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 32/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2183 - binary_accuracy: 0.9188 - precision: 0.9393 - recall: 0.9226 - val_loss: 0.5205 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 33/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2052 - binary_accuracy: 0.9221 - precision: 0.9420 - recall: 0.9244 - val_loss: 0.7269 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 34/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1986 - binary_accuracy: 0.9302 - precision: 0.9503 - recall: 0.9304 - val_loss: 0.6694 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 35/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2011 - binary_accuracy: 0.9328 - precision: 0.9521 - recall: 0.9337 - val_loss: 0.3962 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 36/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1923 - binary_accuracy: 0.9231 - precision: 0.9421 - recall: 0.9260 - val_loss: 0.5121 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 37/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.2123 - binary_accuracy: 0.9266 - precision: 0.9417 - recall: 0.9341 - val_loss: 0.5634 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 38/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1983 - binary_accuracy: 0.9298 - precision: 0.9518 - recall: 0.9297 - val_loss: 0.6676 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 39/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.1942 - binary_accuracy: 0.9244 - precision: 0.9457 - recall: 0.9280 - val_loss: 0.4752 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 40/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1840 - binary_accuracy: 0.9321 - precision: 0.9523 - recall: 0.9286 - val_loss: 0.3392 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 41/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2204 - binary_accuracy: 0.9157 - precision: 0.9360 - recall: 0.9224 - val_loss: 0.4573 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 42/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2067 - binary_accuracy: 0.9295 - precision: 0.9430 - recall: 0.9344 - val_loss: 0.4475 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 43/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.2110 - binary_accuracy: 0.9279 - precision: 0.9511 - recall: 0.9255 - val_loss: 0.5060 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 44/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1977 - binary_accuracy: 0.9263 - precision: 0.9480 - recall: 0.9253 - val_loss: 0.4843 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 45/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1838 - binary_accuracy: 0.9270 - precision: 0.9519 - recall: 0.9193 - val_loss: 0.4375 - val_binary_accuracy: 0.7500 - val_precision: 0.8333 - val_recall: 0.6250
# Epoch 46/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1771 - binary_accuracy: 0.9355 - precision: 0.9529 - recall: 0.9365 - val_loss: 0.3017 - val_binary_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 47/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1818 - binary_accuracy: 0.9300 - precision: 0.9463 - recall: 0.9368 - val_loss: 0.4540 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 48/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.1915 - binary_accuracy: 0.9335 - precision: 0.9501 - recall: 0.9362 - val_loss: 0.2758 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 49/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1720 - binary_accuracy: 0.9373 - precision: 0.9569 - recall: 0.9347 - val_loss: 0.4538 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 50/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2014 - binary_accuracy: 0.9261 - precision: 0.9386 - recall: 0.9357 - val_loss: 0.3676 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 11ms/step - loss: 0.2357 - binary_accuracy: 0.9215 - precision: 0.9231 - recall: 0.9538

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 154.13it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 135.24it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 134.13it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 139.38it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 139.92it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 140.41it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 146.06it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 140.53it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 139.62it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 135.34it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())
