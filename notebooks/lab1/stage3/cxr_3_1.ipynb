# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# =================================================================
# Total params: 6,032
# Trainable params: 6,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,427,921
# Trainable params: 8,427,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 36s 150ms/step - loss: 0.6243 - binary_accuracy: 0.6669 - precision: 0.6825 - recall: 0.7923 - val_loss: 0.5177 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 2/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3606 - binary_accuracy: 0.8510 - precision: 0.8769 - recall: 0.8694 - val_loss: 0.5043 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 3/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3330 - binary_accuracy: 0.8763 - precision: 0.9176 - recall: 0.8690 - val_loss: 0.4341 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 4/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3693 - binary_accuracy: 0.8537 - precision: 0.9051 - recall: 0.8419 - val_loss: 0.3890 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 5/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3258 - binary_accuracy: 0.8760 - precision: 0.9262 - recall: 0.8593 - val_loss: 0.4369 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 6/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3557 - binary_accuracy: 0.8581 - precision: 0.9238 - recall: 0.8293 - val_loss: 0.4157 - val_binary_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 7/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3353 - binary_accuracy: 0.8764 - precision: 0.9244 - recall: 0.8635 - val_loss: 0.4167 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 8/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3116 - binary_accuracy: 0.8797 - precision: 0.9287 - recall: 0.8686 - val_loss: 0.4788 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 9/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3130 - binary_accuracy: 0.8786 - precision: 0.9308 - recall: 0.8626 - val_loss: 0.4578 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 10/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2935 - binary_accuracy: 0.8879 - precision: 0.9321 - recall: 0.8753 - val_loss: 0.4813 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 11/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2830 - binary_accuracy: 0.8925 - precision: 0.9410 - recall: 0.8728 - val_loss: 0.4079 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 12/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2726 - binary_accuracy: 0.9003 - precision: 0.9331 - recall: 0.8939 - val_loss: 0.4190 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 13/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2877 - binary_accuracy: 0.8958 - precision: 0.9360 - recall: 0.8855 - val_loss: 0.3679 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 14/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2780 - binary_accuracy: 0.8887 - precision: 0.9292 - recall: 0.8789 - val_loss: 0.4750 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 15/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2674 - binary_accuracy: 0.9000 - precision: 0.9389 - recall: 0.8888 - val_loss: 0.4428 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 16/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2814 - binary_accuracy: 0.8940 - precision: 0.9377 - recall: 0.8798 - val_loss: 0.3932 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 17/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2764 - binary_accuracy: 0.8914 - precision: 0.9297 - recall: 0.8856 - val_loss: 0.3936 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 18/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2687 - binary_accuracy: 0.8918 - precision: 0.9290 - recall: 0.8902 - val_loss: 0.4390 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 19/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2576 - binary_accuracy: 0.9034 - precision: 0.9432 - recall: 0.8900 - val_loss: 0.4484 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 20/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2426 - binary_accuracy: 0.9008 - precision: 0.9347 - recall: 0.8993 - val_loss: 0.5261 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 21/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2502 - binary_accuracy: 0.8993 - precision: 0.9272 - recall: 0.9020 - val_loss: 0.3741 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 22/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2521 - binary_accuracy: 0.8990 - precision: 0.9383 - recall: 0.8864 - val_loss: 0.3763 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 23/50
# 205/205 [==============================] - ETA: 0s - loss: 0.2589 - binary_accuracy: 0.9012 - precision: 0.9495 - recall: 0.87 - 30s 145ms/step - loss: 0.2588 - binary_accuracy: 0.9012 - precision: 0.9495 - recall: 0.8799 - val_loss: 0.4098 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 24/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2585 - binary_accuracy: 0.8986 - precision: 0.9290 - recall: 0.8980 - val_loss: 0.5907 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 25/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2712 - binary_accuracy: 0.8985 - precision: 0.9391 - recall: 0.8856 - val_loss: 0.6295 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 26/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2368 - binary_accuracy: 0.9145 - precision: 0.9464 - recall: 0.9104 - val_loss: 0.6684 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 27/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2471 - binary_accuracy: 0.9035 - precision: 0.9430 - recall: 0.8904 - val_loss: 0.3906 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 28/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2341 - binary_accuracy: 0.9091 - precision: 0.9371 - recall: 0.9038 - val_loss: 0.5378 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 29/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2167 - binary_accuracy: 0.9150 - precision: 0.9455 - recall: 0.9084 - val_loss: 0.4669 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 30/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2316 - binary_accuracy: 0.9111 - precision: 0.9442 - recall: 0.9064 - val_loss: 0.4192 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 31/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2091 - binary_accuracy: 0.9169 - precision: 0.9354 - recall: 0.9223 - val_loss: 0.4843 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 32/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.2263 - binary_accuracy: 0.9106 - precision: 0.9366 - recall: 0.9136 - val_loss: 0.3777 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 33/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2155 - binary_accuracy: 0.9165 - precision: 0.9410 - recall: 0.9177 - val_loss: 0.3555 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 34/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2144 - binary_accuracy: 0.9138 - precision: 0.9451 - recall: 0.9048 - val_loss: 0.3726 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 35/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2091 - binary_accuracy: 0.9194 - precision: 0.9447 - recall: 0.9164 - val_loss: 0.3346 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 36/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2166 - binary_accuracy: 0.9175 - precision: 0.9479 - recall: 0.9142 - val_loss: 0.4244 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 37/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2150 - binary_accuracy: 0.9145 - precision: 0.9474 - recall: 0.9022 - val_loss: 0.4778 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 38/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2140 - binary_accuracy: 0.9146 - precision: 0.9411 - recall: 0.9135 - val_loss: 0.8979 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 39/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2066 - binary_accuracy: 0.9217 - precision: 0.9518 - recall: 0.9127 - val_loss: 0.5283 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 40/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2362 - binary_accuracy: 0.9057 - precision: 0.9377 - recall: 0.8984 - val_loss: 0.7341 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 41/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2172 - binary_accuracy: 0.9149 - precision: 0.9416 - recall: 0.9124 - val_loss: 0.6558 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 42/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.1968 - binary_accuracy: 0.9271 - precision: 0.9618 - recall: 0.9136 - val_loss: 0.4173 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 43/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2059 - binary_accuracy: 0.9158 - precision: 0.9536 - recall: 0.9046 - val_loss: 0.6582 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 44/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.2138 - binary_accuracy: 0.9163 - precision: 0.9482 - recall: 0.9108 - val_loss: 0.5756 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 45/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.2359 - binary_accuracy: 0.9069 - precision: 0.9419 - recall: 0.9005 - val_loss: 0.6853 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 46/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.1887 - binary_accuracy: 0.9288 - precision: 0.9592 - recall: 0.9181 - val_loss: 1.0100 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 47/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.2291 - binary_accuracy: 0.9191 - precision: 0.9447 - recall: 0.9160 - val_loss: 0.9590 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 48/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.2135 - binary_accuracy: 0.9172 - precision: 0.9393 - recall: 0.9223 - val_loss: 0.5582 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 49/50
# 205/205 [==============================] - 29s 143ms/step - loss: 0.1856 - binary_accuracy: 0.9299 - precision: 0.9511 - recall: 0.9310 - val_loss: 0.6333 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 50/50
# 205/205 [==============================] - ETA: 0s - loss: 0.2131 - binary_accuracy: 0.9118 - precision: 0.9370 - recall: 0.91 - 29s 143ms/step - loss: 0.2131 - binary_accuracy: 0.9118 - precision: 0.9371 - recall: 0.9129 - val_loss: 0.4651 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 11ms/step - loss: 0.2671 - binary_accuracy: 0.8862 - precision: 0.9443 - recall: 0.8692

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 157.59it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 139.59it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 138.00it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 142.85it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 142.05it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 142.52it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 147.89it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 144.22it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 141.05it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 139.87it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())
