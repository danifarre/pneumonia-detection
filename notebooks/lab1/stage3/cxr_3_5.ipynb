# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 99,760
# Trainable params: 99,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,230,193
# Trainable params: 2,230,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 34s 156ms/step - loss: 0.6254 - binary_accuracy: 0.6285 - precision: 0.6373 - recall: 0.8754 - val_loss: 0.5566 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 2/50
# 205/205 [==============================] - 31s 152ms/step - loss: 0.3744 - binary_accuracy: 0.8553 - precision: 0.8982 - recall: 0.8609 - val_loss: 0.5004 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 3/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.3347 - binary_accuracy: 0.8749 - precision: 0.9196 - recall: 0.8651 - val_loss: 0.5661 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 4/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.3152 - binary_accuracy: 0.8814 - precision: 0.9133 - recall: 0.8818 - val_loss: 0.5073 - val_binary_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.7500
# Epoch 5/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.3141 - binary_accuracy: 0.8768 - precision: 0.9245 - recall: 0.8608 - val_loss: 0.8991 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 6/50
# 205/205 [==============================] - 31s 153ms/step - loss: 0.2921 - binary_accuracy: 0.8874 - precision: 0.9312 - recall: 0.8749 - val_loss: 0.4617 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 7/50
# 205/205 [==============================] - 31s 152ms/step - loss: 0.3017 - binary_accuracy: 0.8824 - precision: 0.9327 - recall: 0.8592 - val_loss: 0.3787 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 8/50
# 205/205 [==============================] - 31s 152ms/step - loss: 0.3168 - binary_accuracy: 0.8743 - precision: 0.9201 - recall: 0.8668 - val_loss: 0.3991 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 9/50
# 205/205 [==============================] - 31s 152ms/step - loss: 0.3110 - binary_accuracy: 0.8855 - precision: 0.9342 - recall: 0.8660 - val_loss: 0.6069 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 10/50
# 205/205 [==============================] - 31s 152ms/step - loss: 0.2859 - binary_accuracy: 0.8906 - precision: 0.9415 - recall: 0.8709 - val_loss: 0.4591 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 11/50
# 205/205 [==============================] - 31s 151ms/step - loss: 0.2871 - binary_accuracy: 0.8828 - precision: 0.9258 - recall: 0.8703 - val_loss: 0.5810 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 12/50
# 205/205 [==============================] - 31s 150ms/step - loss: 0.2881 - binary_accuracy: 0.8900 - precision: 0.9298 - recall: 0.8780 - val_loss: 0.4211 - val_binary_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 13/50
# 205/205 [==============================] - 31s 151ms/step - loss: 0.2393 - binary_accuracy: 0.9062 - precision: 0.9424 - recall: 0.8979 - val_loss: 0.6036 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 14/50
# 205/205 [==============================] - 31s 150ms/step - loss: 0.2515 - binary_accuracy: 0.9006 - precision: 0.9354 - recall: 0.8917 - val_loss: 0.3945 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 15/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2739 - binary_accuracy: 0.9026 - precision: 0.9440 - recall: 0.8862 - val_loss: 0.4088 - val_binary_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.7500
# Epoch 16/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2682 - binary_accuracy: 0.9028 - precision: 0.9390 - recall: 0.8996 - val_loss: 0.5505 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 17/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2588 - binary_accuracy: 0.8992 - precision: 0.9344 - recall: 0.8918 - val_loss: 0.8285 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 18/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2559 - binary_accuracy: 0.9003 - precision: 0.9308 - recall: 0.8998 - val_loss: 0.6045 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 19/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2363 - binary_accuracy: 0.9018 - precision: 0.9342 - recall: 0.8971 - val_loss: 0.4294 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 20/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2312 - binary_accuracy: 0.9155 - precision: 0.9424 - recall: 0.9106 - val_loss: 0.4734 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 21/50
# 205/205 [==============================] - ETA: 0s - loss: 0.2342 - binary_accuracy: 0.9083 - precision: 0.9403 - recall: 0.89 - 30s 146ms/step - loss: 0.2342 - binary_accuracy: 0.9083 - precision: 0.9403 - recall: 0.8989 - val_loss: 0.3539 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 22/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2429 - binary_accuracy: 0.9030 - precision: 0.9395 - recall: 0.8950 - val_loss: 0.4415 - val_binary_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.7500
# Epoch 23/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2273 - binary_accuracy: 0.9147 - precision: 0.9441 - recall: 0.9105 - val_loss: 0.5552 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 24/50
# 205/205 [==============================] - 31s 150ms/step - loss: 0.2537 - binary_accuracy: 0.9031 - precision: 0.9300 - recall: 0.9000 - val_loss: 0.2616 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.8750
# Epoch 25/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2285 - binary_accuracy: 0.9124 - precision: 0.9462 - recall: 0.9000 - val_loss: 0.5300 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 26/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2345 - binary_accuracy: 0.9080 - precision: 0.9344 - recall: 0.9124 - val_loss: 0.3488 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 27/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2419 - binary_accuracy: 0.9068 - precision: 0.9422 - recall: 0.8999 - val_loss: 0.3783 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 28/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2105 - binary_accuracy: 0.9219 - precision: 0.9541 - recall: 0.9116 - val_loss: 0.3835 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 29/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2289 - binary_accuracy: 0.9100 - precision: 0.9438 - recall: 0.8989 - val_loss: 0.4016 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 30/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2177 - binary_accuracy: 0.9131 - precision: 0.9431 - recall: 0.9085 - val_loss: 0.3376 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 31/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2259 - binary_accuracy: 0.9122 - precision: 0.9455 - recall: 0.9056 - val_loss: 0.3743 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 32/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.1958 - binary_accuracy: 0.9280 - precision: 0.9525 - recall: 0.9250 - val_loss: 0.3180 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 33/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1931 - binary_accuracy: 0.9209 - precision: 0.9517 - recall: 0.9169 - val_loss: 0.7032 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 34/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.1883 - binary_accuracy: 0.9265 - precision: 0.9590 - recall: 0.9147 - val_loss: 0.6227 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 35/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2046 - binary_accuracy: 0.9250 - precision: 0.9512 - recall: 0.9194 - val_loss: 0.3961 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 36/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2040 - binary_accuracy: 0.9299 - precision: 0.9537 - recall: 0.9267 - val_loss: 0.7489 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 37/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2176 - binary_accuracy: 0.9212 - precision: 0.9434 - recall: 0.9200 - val_loss: 0.4161 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 38/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.1966 - binary_accuracy: 0.9308 - precision: 0.9632 - recall: 0.9180 - val_loss: 0.6857 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 39/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2078 - binary_accuracy: 0.9203 - precision: 0.9454 - recall: 0.9171 - val_loss: 0.3366 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 40/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2023 - binary_accuracy: 0.9257 - precision: 0.9566 - recall: 0.9196 - val_loss: 0.4742 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 41/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2184 - binary_accuracy: 0.9258 - precision: 0.9524 - recall: 0.9197 - val_loss: 0.6605 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 42/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1869 - binary_accuracy: 0.9312 - precision: 0.9529 - recall: 0.9280 - val_loss: 0.3854 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 43/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1828 - binary_accuracy: 0.9259 - precision: 0.9542 - recall: 0.9175 - val_loss: 0.4347 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 44/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2221 - binary_accuracy: 0.9216 - precision: 0.9533 - recall: 0.9125 - val_loss: 0.3724 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 45/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1813 - binary_accuracy: 0.9279 - precision: 0.9499 - recall: 0.9241 - val_loss: 0.3522 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 46/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1880 - binary_accuracy: 0.9299 - precision: 0.9508 - recall: 0.9263 - val_loss: 0.4078 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 47/50
# 205/205 [==============================] - 30s 149ms/step - loss: 0.1935 - binary_accuracy: 0.9238 - precision: 0.9520 - recall: 0.9206 - val_loss: 0.3458 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 48/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1932 - binary_accuracy: 0.9276 - precision: 0.9488 - recall: 0.9254 - val_loss: 0.3809 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 49/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1994 - binary_accuracy: 0.9220 - precision: 0.9477 - recall: 0.9157 - val_loss: 0.4429 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 50/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1774 - binary_accuracy: 0.9296 - precision: 0.9544 - recall: 0.9261 - val_loss: 0.5323 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 12ms/step - loss: 0.2471 - binary_accuracy: 0.9103 - precision: 0.9304 - recall: 0.9256

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 142.85it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.52it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.23it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 125.21it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 125.33it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.10it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 127.07it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 124.61it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 124.71it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.51it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())
