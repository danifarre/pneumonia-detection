# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 99,760
# Trainable params: 99,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,230,193
# Trainable params: 2,230,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 32s 146ms/step - loss: 0.6165 - binary_accuracy: 0.6308 - precision: 0.6581 - recall: 0.7899 - val_loss: 0.5722 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 2/50
# 205/205 [==============================] - 29s 140ms/step - loss: 0.3957 - binary_accuracy: 0.8439 - precision: 0.8872 - recall: 0.8404 - val_loss: 1.2058 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 3/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3842 - binary_accuracy: 0.8441 - precision: 0.9026 - recall: 0.8234 - val_loss: 0.6599 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 4/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3429 - binary_accuracy: 0.8704 - precision: 0.9148 - recall: 0.8641 - val_loss: 0.6116 - val_binary_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 5/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3324 - binary_accuracy: 0.8726 - precision: 0.9169 - recall: 0.8598 - val_loss: 0.7625 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 6/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3007 - binary_accuracy: 0.8888 - precision: 0.9351 - recall: 0.8715 - val_loss: 0.6104 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 7/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2977 - binary_accuracy: 0.8923 - precision: 0.9270 - recall: 0.8865 - val_loss: 0.8024 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 8/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3386 - binary_accuracy: 0.8791 - precision: 0.9237 - recall: 0.8626 - val_loss: 0.5994 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 9/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2818 - binary_accuracy: 0.8929 - precision: 0.9323 - recall: 0.8801 - val_loss: 0.5243 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 10/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2816 - binary_accuracy: 0.8978 - precision: 0.9388 - recall: 0.8909 - val_loss: 0.5368 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 11/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2688 - binary_accuracy: 0.8949 - precision: 0.9179 - recall: 0.9058 - val_loss: 0.6222 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 12/50
# 205/205 [==============================] - 29s 142ms/step - loss: 0.2680 - binary_accuracy: 0.8990 - precision: 0.9318 - recall: 0.8931 - val_loss: 0.4463 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 13/50
# 205/205 [==============================] - 29s 144ms/step - loss: 0.2584 - binary_accuracy: 0.9080 - precision: 0.9386 - recall: 0.8957 - val_loss: 0.5021 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 14/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2675 - binary_accuracy: 0.8949 - precision: 0.9392 - recall: 0.8803 - val_loss: 0.4641 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 15/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2748 - binary_accuracy: 0.8968 - precision: 0.9289 - recall: 0.8931 - val_loss: 0.3850 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 16/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2529 - binary_accuracy: 0.9049 - precision: 0.9375 - recall: 0.8938 - val_loss: 0.6222 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 17/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2624 - binary_accuracy: 0.8938 - precision: 0.9186 - recall: 0.8948 - val_loss: 0.4702 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 18/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2243 - binary_accuracy: 0.9223 - precision: 0.9485 - recall: 0.9176 - val_loss: 0.6221 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 19/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2514 - binary_accuracy: 0.9048 - precision: 0.9291 - recall: 0.9102 - val_loss: 0.4933 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 20/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2259 - binary_accuracy: 0.9177 - precision: 0.9466 - recall: 0.9104 - val_loss: 0.8534 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 21/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2352 - binary_accuracy: 0.9195 - precision: 0.9432 - recall: 0.9187 - val_loss: 0.3583 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 22/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2277 - binary_accuracy: 0.9253 - precision: 0.9550 - recall: 0.9136 - val_loss: 0.8944 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 23/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2446 - binary_accuracy: 0.9147 - precision: 0.9406 - recall: 0.9160 - val_loss: 0.6568 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 24/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.1981 - binary_accuracy: 0.9191 - precision: 0.9352 - recall: 0.9270 - val_loss: 1.4907 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 25/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2059 - binary_accuracy: 0.9216 - precision: 0.9366 - recall: 0.9282 - val_loss: 1.0856 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 26/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2096 - binary_accuracy: 0.9221 - precision: 0.9444 - recall: 0.9225 - val_loss: 0.3667 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 27/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2165 - binary_accuracy: 0.9167 - precision: 0.9403 - recall: 0.9161 - val_loss: 0.4740 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 28/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2113 - binary_accuracy: 0.9191 - precision: 0.9348 - recall: 0.9237 - val_loss: 0.5071 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 29/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1978 - binary_accuracy: 0.9322 - precision: 0.9498 - recall: 0.9358 - val_loss: 0.7812 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 30/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2043 - binary_accuracy: 0.9218 - precision: 0.9395 - recall: 0.9261 - val_loss: 0.9402 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 31/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1778 - binary_accuracy: 0.9360 - precision: 0.9518 - recall: 0.9390 - val_loss: 0.4722 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 32/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1859 - binary_accuracy: 0.9318 - precision: 0.9498 - recall: 0.9355 - val_loss: 0.7093 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 33/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1927 - binary_accuracy: 0.9208 - precision: 0.9438 - recall: 0.9235 - val_loss: 0.5329 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 34/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1750 - binary_accuracy: 0.9303 - precision: 0.9502 - recall: 0.9348 - val_loss: 0.4410 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 35/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1827 - binary_accuracy: 0.9284 - precision: 0.9493 - recall: 0.9290 - val_loss: 0.4560 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 36/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1906 - binary_accuracy: 0.9282 - precision: 0.9506 - recall: 0.9268 - val_loss: 0.5901 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 37/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1863 - binary_accuracy: 0.9333 - precision: 0.9529 - recall: 0.9317 - val_loss: 0.4673 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 38/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1708 - binary_accuracy: 0.9416 - precision: 0.9599 - recall: 0.9405 - val_loss: 0.5899 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 39/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1864 - binary_accuracy: 0.9347 - precision: 0.9510 - recall: 0.9394 - val_loss: 0.8250 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 40/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1836 - binary_accuracy: 0.9346 - precision: 0.9536 - recall: 0.9337 - val_loss: 0.3771 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 41/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1968 - binary_accuracy: 0.9324 - precision: 0.9513 - recall: 0.9333 - val_loss: 0.5776 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 42/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1850 - binary_accuracy: 0.9334 - precision: 0.9628 - recall: 0.9241 - val_loss: 0.5776 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 43/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.2079 - binary_accuracy: 0.9284 - precision: 0.9480 - recall: 0.9261 - val_loss: 0.7926 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 44/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1713 - binary_accuracy: 0.9351 - precision: 0.9536 - recall: 0.9349 - val_loss: 0.5263 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 45/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1770 - binary_accuracy: 0.9326 - precision: 0.9590 - recall: 0.9252 - val_loss: 1.2052 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 46/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1488 - binary_accuracy: 0.9442 - precision: 0.9557 - recall: 0.9504 - val_loss: 0.7684 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 47/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1818 - binary_accuracy: 0.9400 - precision: 0.9663 - recall: 0.9292 - val_loss: 0.6744 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 48/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1681 - binary_accuracy: 0.9378 - precision: 0.9574 - recall: 0.9330 - val_loss: 0.5172 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 49/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1777 - binary_accuracy: 0.9326 - precision: 0.9490 - recall: 0.9366 - val_loss: 1.4201 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 50/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1596 - binary_accuracy: 0.9387 - precision: 0.9573 - recall: 0.9401 - val_loss: 1.3597 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 12ms/step - loss: 0.4743 - binary_accuracy: 0.8702 - precision: 0.8366 - recall: 0.9846

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 144.80it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 118.67it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 117.23it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.05it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.51it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 120.69it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 126.69it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.96it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.45it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 118.99it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())
