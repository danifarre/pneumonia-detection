# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=8, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# =================================================================
# Total params: 6,616
# Trainable params: 6,616
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,137,049
# Trainable params: 2,137,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 87s 583ms/step - loss: 0.6992 - binary_accuracy: 0.5221 - precision: 0.5333 - recall: 0.3586 - val_loss: 0.5373 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 2/100
# 144/144 [==============================] - 84s 584ms/step - loss: 0.6344 - binary_accuracy: 0.6421 - precision: 0.6432 - recall: 0.6214 - val_loss: 0.4685 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 3/100
# 144/144 [==============================] - 85s 588ms/step - loss: 0.5962 - binary_accuracy: 0.6939 - precision: 0.6959 - recall: 0.6832 - val_loss: 0.6129 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 85s 589ms/step - loss: 0.5996 - binary_accuracy: 0.6878 - precision: 0.6871 - recall: 0.6675 - val_loss: 0.4659 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 5/100
# 144/144 [==============================] - 86s 594ms/step - loss: 0.5920 - binary_accuracy: 0.6926 - precision: 0.6923 - recall: 0.6814 - val_loss: 0.6258 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 81s 561ms/step - loss: 0.5837 - binary_accuracy: 0.6977 - precision: 0.6996 - recall: 0.6656 - val_loss: 0.5117 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 91/100
# 144/144 [==============================] - 93s 642ms/step - loss: 0.5372 - binary_accuracy: 0.7409 - precision: 0.7324 - recall: 0.7438 - val_loss: 0.4398 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 92/100
# 144/144 [==============================] - 92s 639ms/step - loss: 0.5473 - binary_accuracy: 0.7260 - precision: 0.7145 - recall: 0.7201 - val_loss: 0.3790 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 93/100
# 144/144 [==============================] - 92s 640ms/step - loss: 0.5477 - binary_accuracy: 0.7314 - precision: 0.7285 - recall: 0.7387 - val_loss: 0.4390 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 92s 640ms/step - loss: 0.5386 - binary_accuracy: 0.7340 - precision: 0.7260 - recall: 0.7507 - val_loss: 0.3825 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 92s 640ms/step - loss: 0.5479 - binary_accuracy: 0.7301 - precision: 0.7248 - recall: 0.7352 - val_loss: 0.3393 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 93s 647ms/step - loss: 0.5411 - binary_accuracy: 0.7337 - precision: 0.7368 - recall: 0.7310 - val_loss: 0.3962 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 97/100
# 144/144 [==============================] - 93s 643ms/step - loss: 0.5391 - binary_accuracy: 0.7398 - precision: 0.7381 - recall: 0.7302 - val_loss: 0.3946 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 93s 644ms/step - loss: 0.5409 - binary_accuracy: 0.7364 - precision: 0.7323 - recall: 0.7328 - val_loss: 0.4255 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 93s 649ms/step - loss: 0.5381 - binary_accuracy: 0.7346 - precision: 0.7294 - recall: 0.7379 - val_loss: 0.3919 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 94s 648ms/step - loss: 0.5376 - binary_accuracy: 0.7352 - precision: 0.7308 - recall: 0.7243 - val_loss: 0.4349 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 13ms/step - loss: 0.5099 - binary_accuracy: 0.7604 - precision: 0.7316 - recall: 0.8015

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:15<00:00, 64.19it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 68.21it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 70.76it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 71.31it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 67.20it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 68.46it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 71.92it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 70.50it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 67.72it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 65.57it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
