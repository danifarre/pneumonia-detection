# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# =================================================================
# Total params: 6,032
# Trainable params: 6,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,427,921
# Trainable params: 8,427,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 88s 567ms/step - loss: 0.7390 - binary_accuracy: 0.5243 - precision: 0.5284 - recall: 0.4276 - val_loss: 0.6899 - val_binary_accuracy: 0.5000 - val_precision: 0.2857 - val_recall: 1.0000
# Epoch 2/100
# 144/144 [==============================] - 81s 565ms/step - loss: 0.6486 - binary_accuracy: 0.6207 - precision: 0.6111 - recall: 0.6129 - val_loss: 0.5015 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 3/100
# 144/144 [==============================] - 81s 565ms/step - loss: 0.6417 - binary_accuracy: 0.6420 - precision: 0.6360 - recall: 0.6356 - val_loss: 0.6053 - val_binary_accuracy: 0.6000 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 80s 558ms/step - loss: 0.6272 - binary_accuracy: 0.6600 - precision: 0.6578 - recall: 0.6727 - val_loss: 0.6313 - val_binary_accuracy: 0.6000 - val_precision: 0.3000 - val_recall: 0.7500
# Epoch 5/100
# 144/144 [==============================] - 80s 554ms/step - loss: 0.6179 - binary_accuracy: 0.6718 - precision: 0.6706 - recall: 0.6609 - val_loss: 0.6140 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 79s 547ms/step - loss: 0.6133 - binary_accuracy: 0.6728 - precision: 0.6696 - recall: 0.6854 - val_loss: 0.5386 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 90/100
# 144/144 [==============================] - 92s 635ms/step - loss: 0.5577 - binary_accuracy: 0.7164 - precision: 0.7139 - recall: 0.7257 - val_loss: 0.4664 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 91/100
# 144/144 [==============================] - 92s 637ms/step - loss: 0.5543 - binary_accuracy: 0.7227 - precision: 0.7230 - recall: 0.7060 - val_loss: 0.3918 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 92/100
# 144/144 [==============================] - 92s 638ms/step - loss: 0.5566 - binary_accuracy: 0.7223 - precision: 0.7230 - recall: 0.7153 - val_loss: 0.5482 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 93/100
# 144/144 [==============================] - 92s 640ms/step - loss: 0.5548 - binary_accuracy: 0.7233 - precision: 0.7196 - recall: 0.7251 - val_loss: 0.3928 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 92s 641ms/step - loss: 0.5360 - binary_accuracy: 0.7447 - precision: 0.7426 - recall: 0.7258 - val_loss: 0.4706 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 93s 645ms/step - loss: 0.5468 - binary_accuracy: 0.7331 - precision: 0.7330 - recall: 0.7255 - val_loss: 0.4270 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 93s 642ms/step - loss: 0.5603 - binary_accuracy: 0.7218 - precision: 0.7275 - recall: 0.7078 - val_loss: 0.4598 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 93s 647ms/step - loss: 0.5488 - binary_accuracy: 0.7269 - precision: 0.7321 - recall: 0.7123 - val_loss: 0.5511 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 93s 645ms/step - loss: 0.5594 - binary_accuracy: 0.7200 - precision: 0.7143 - recall: 0.7220 - val_loss: 0.4236 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 94s 650ms/step - loss: 0.5588 - binary_accuracy: 0.7191 - precision: 0.7184 - recall: 0.6975 - val_loss: 0.3761 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 100/100
# 144/144 [==============================] - 93s 644ms/step - loss: 0.5460 - binary_accuracy: 0.7322 - precision: 0.7311 - recall: 0.7223 - val_loss: 0.5422 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 13ms/step - loss: 0.5512 - binary_accuracy: 0.7320 - precision: 0.6816 - recall: 0.8428

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:15<00:00, 66.11it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 68.26it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 70.68it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 70.84it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 69.05it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 69.82it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 73.45it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 70.57it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 68.78it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 66.03it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
