# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# =================================================================
# Total params: 6,032
# Trainable params: 6,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,427,921
# Trainable params: 8,427,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 87s 581ms/step - loss: 0.7218 - binary_accuracy: 0.5243 - precision: 0.5324 - recall: 0.2640 - val_loss: 0.6556 - val_binary_accuracy: 0.6000 - val_precision: 0.3000 - val_recall: 0.7500
# Epoch 2/100
# 144/144 [==============================] - 84s 579ms/step - loss: 0.6615 - binary_accuracy: 0.6032 - precision: 0.5910 - recall: 0.6106 - val_loss: 0.5423 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 3/100
# 144/144 [==============================] - 84s 581ms/step - loss: 0.6358 - binary_accuracy: 0.6472 - precision: 0.6349 - recall: 0.6567 - val_loss: 0.6243 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 84s 585ms/step - loss: 0.6180 - binary_accuracy: 0.6704 - precision: 0.6629 - recall: 0.6800 - val_loss: 0.5788 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 5/100
# 144/144 [==============================] - 84s 582ms/step - loss: 0.6103 - binary_accuracy: 0.6733 - precision: 0.6668 - recall: 0.6653 - val_loss: 0.5906 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 84s 582ms/step - loss: 0.6099 - binary_accuracy: 0.6861 - precision: 0.6765 - recall: 0.7069 - val_loss: 0.5862 - val_binary_accuracy: 0.6000 - val_precision: 0.3000 - val_recall: 0.7500
# Epoch 7/100
# 144/144 [==============================] - 84s 584ms/step - loss: 0.6069 - binary_accuracy: 0.6850 - precision: 0.6885 - recall: 0.6562 - val_loss: 0.5809 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 92s 635ms/step - loss: 0.5524 - binary_accuracy: 0.7249 - precision: 0.7200 - recall: 0.7129 - val_loss: 0.4657 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 92s 637ms/step - loss: 0.5510 - binary_accuracy: 0.7273 - precision: 0.7287 - recall: 0.7265 - val_loss: 0.3984 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 97/100
# 144/144 [==============================] - 92s 637ms/step - loss: 0.5554 - binary_accuracy: 0.7223 - precision: 0.7242 - recall: 0.7090 - val_loss: 0.5057 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 92s 640ms/step - loss: 0.5525 - binary_accuracy: 0.7259 - precision: 0.7200 - recall: 0.7321 - val_loss: 0.3987 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 92s 639ms/step - loss: 0.5453 - binary_accuracy: 0.7308 - precision: 0.7340 - recall: 0.7155 - val_loss: 0.4393 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 92s 642ms/step - loss: 0.5633 - binary_accuracy: 0.7123 - precision: 0.7011 - recall: 0.7200 - val_loss: 0.4917 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 12ms/step - loss: 0.5308 - binary_accuracy: 0.7416 - precision: 0.7050 - recall: 0.8062

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:11<00:00, 88.16it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 77.26it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 77.42it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 80.56it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 76.73it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 72.74it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 77.44it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 78.77it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 75.21it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 79.02it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
