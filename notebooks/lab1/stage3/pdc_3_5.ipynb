# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 99,760
# Trainable params: 99,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,230,193
# Trainable params: 2,230,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 88s 566ms/step - loss: 0.6939 - binary_accuracy: 0.5204 - precision: 0.5050 - recall: 0.4354 - val_loss: 0.5878 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.5000
# Epoch 2/100
# 144/144 [==============================] - 81s 562ms/step - loss: 0.6595 - binary_accuracy: 0.6046 - precision: 0.6114 - recall: 0.5550 - val_loss: 0.5191 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/100
# 144/144 [==============================] - 81s 562ms/step - loss: 0.6071 - binary_accuracy: 0.6823 - precision: 0.6767 - recall: 0.6987 - val_loss: 0.6379 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 81s 562ms/step - loss: 0.5936 - binary_accuracy: 0.6928 - precision: 0.6871 - recall: 0.6839 - val_loss: 0.4229 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 5/100
# 144/144 [==============================] - 82s 566ms/step - loss: 0.5856 - binary_accuracy: 0.7001 - precision: 0.7093 - recall: 0.6738 - val_loss: 0.5602 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 82s 567ms/step - loss: 0.5799 - binary_accuracy: 0.7059 - precision: 0.7150 - recall: 0.6593 - val_loss: 0.4368 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 7/100
# 144/144 [==============================] - 82s 568ms/step - loss: 0.5793 - binary_accuracy: 0.7048 - precision: 0.7118 - recall: 0.6698 - val_loss: 0.5398 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 8/100
# 144/144 [==============================] - 82s 569ms/step - loss: 0.5725 - binary_accuracy: 0.7092 - precision: 0.7218 - recall: 0.6670 - val_loss: 0.4215 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 9/100
# 144/144 [==============================] - 82s 572ms/step - loss: 0.5775 - binary_accuracy: 0.7070 - precision: 0.7100 - recall: 0.6861 - val_loss: 0.4434 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 10/100
# 144/144 [==============================] - 83s 578ms/step - loss: 0.5782 - binary_accuracy: 0.7023 - precision: 0.7091 - recall: 0.6755 - val_loss: 0.4800 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 11/100
# 144/144 [==============================] - 82s 572ms/step - loss: 0.5710 - binary_accuracy: 0.7102 - precision: 0.7132 - recall: 0.6995 - val_loss: 0.4833 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 12/100
# 144/144 [==============================] - 82s 572ms/step - loss: 0.5796 - binary_accuracy: 0.7020 - precision: 0.7149 - recall: 0.6718 - val_loss: 0.5475 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 13/100
# 144/144 [==============================] - 83s 572ms/step - loss: 0.5659 - binary_accuracy: 0.7097 - precision: 0.7118 - recall: 0.6970 - val_loss: 0.4647 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 14/100
# 144/144 [==============================] - 83s 573ms/step - loss: 0.5654 - binary_accuracy: 0.7159 - precision: 0.7111 - recall: 0.7140 - val_loss: 0.6078 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 15/100
# 144/144 [==============================] - 83s 573ms/step - loss: 0.5619 - binary_accuracy: 0.7218 - precision: 0.7285 - recall: 0.7004 - val_loss: 0.5820 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 16/100
# 144/144 [==============================] - 83s 574ms/step - loss: 0.5692 - binary_accuracy: 0.7095 - precision: 0.7088 - recall: 0.7014 - val_loss: 0.5575 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 17/100
# 144/144 [==============================] - 83s 577ms/step - loss: 0.5665 - binary_accuracy: 0.7225 - precision: 0.7308 - recall: 0.6984 - val_loss: 0.5191 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 18/100
# 144/144 [==============================] - 83s 578ms/step - loss: 0.5713 - binary_accuracy: 0.7141 - precision: 0.7134 - recall: 0.6970 - val_loss: 0.4812 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 19/100
# 144/144 [==============================] - 84s 581ms/step - loss: 0.5512 - binary_accuracy: 0.7266 - precision: 0.7252 - recall: 0.7305 - val_loss: 0.4711 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 20/100
# 144/144 [==============================] - 86s 595ms/step - loss: 0.5628 - binary_accuracy: 0.7162 - precision: 0.7219 - recall: 0.6959 - val_loss: 0.4975 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 21/100
# 144/144 [==============================] - 85s 593ms/step - loss: 0.5558 - binary_accuracy: 0.7260 - precision: 0.7261 - recall: 0.7312 - val_loss: 0.6128 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 22/100
# 144/144 [==============================] - 86s 595ms/step - loss: 0.5577 - binary_accuracy: 0.7256 - precision: 0.7303 - recall: 0.7023 - val_loss: 0.4864 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 23/100
# 144/144 [==============================] - 86s 596ms/step - loss: 0.5573 - binary_accuracy: 0.7216 - precision: 0.7201 - recall: 0.7125 - val_loss: 0.5753 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 24/100
# 144/144 [==============================] - 86s 598ms/step - loss: 0.5671 - binary_accuracy: 0.7079 - precision: 0.7058 - recall: 0.6981 - val_loss: 0.5325 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 25/100
# 144/144 [==============================] - 86s 599ms/step - loss: 0.5576 - binary_accuracy: 0.7193 - precision: 0.7259 - recall: 0.6979 - val_loss: 0.3813 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 26/100
# 144/144 [==============================] - 86s 600ms/step - loss: 0.5610 - binary_accuracy: 0.7203 - precision: 0.7295 - recall: 0.7020 - val_loss: 0.4823 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 27/100
# 144/144 [==============================] - 87s 602ms/step - loss: 0.5578 - binary_accuracy: 0.7223 - precision: 0.7235 - recall: 0.7207 - val_loss: 0.5238 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 28/100
# 144/144 [==============================] - 87s 603ms/step - loss: 0.5541 - binary_accuracy: 0.7218 - precision: 0.7237 - recall: 0.7110 - val_loss: 0.4124 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 29/100
# 144/144 [==============================] - 87s 605ms/step - loss: 0.5527 - binary_accuracy: 0.7206 - precision: 0.7247 - recall: 0.7114 - val_loss: 0.4341 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 30/100
# 144/144 [==============================] - 87s 606ms/step - loss: 0.5540 - binary_accuracy: 0.7215 - precision: 0.7191 - recall: 0.7069 - val_loss: 0.4572 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 31/100
# 144/144 [==============================] - 88s 611ms/step - loss: 0.5463 - binary_accuracy: 0.7306 - precision: 0.7223 - recall: 0.7411 - val_loss: 0.4139 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 32/100
# 144/144 [==============================] - 88s 612ms/step - loss: 0.5519 - binary_accuracy: 0.7225 - precision: 0.7289 - recall: 0.7112 - val_loss: 0.5410 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 33/100
# 144/144 [==============================] - 88s 614ms/step - loss: 0.5555 - binary_accuracy: 0.7221 - precision: 0.7199 - recall: 0.7086 - val_loss: 0.4724 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 34/100
# 144/144 [==============================] - 89s 616ms/step - loss: 0.5523 - binary_accuracy: 0.7310 - precision: 0.7215 - recall: 0.7295 - val_loss: 0.4660 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 35/100
# 144/144 [==============================] - 89s 616ms/step - loss: 0.5426 - binary_accuracy: 0.7333 - precision: 0.7382 - recall: 0.7299 - val_loss: 0.3585 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 36/100
# 144/144 [==============================] - 89s 618ms/step - loss: 0.5394 - binary_accuracy: 0.7286 - precision: 0.7237 - recall: 0.7196 - val_loss: 0.4632 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 37/100
# 144/144 [==============================] - 90s 622ms/step - loss: 0.5362 - binary_accuracy: 0.7383 - precision: 0.7283 - recall: 0.7444 - val_loss: 0.3743 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 38/100
# 144/144 [==============================] - 90s 622ms/step - loss: 0.5475 - binary_accuracy: 0.7304 - precision: 0.7347 - recall: 0.7220 - val_loss: 0.5628 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 39/100
# 144/144 [==============================] - 90s 624ms/step - loss: 0.5488 - binary_accuracy: 0.7278 - precision: 0.7216 - recall: 0.7348 - val_loss: 0.4452 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 40/100
# 144/144 [==============================] - 91s 629ms/step - loss: 0.5443 - binary_accuracy: 0.7364 - precision: 0.7365 - recall: 0.7334 - val_loss: 0.4582 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 41/100
# 144/144 [==============================] - 90s 627ms/step - loss: 0.5484 - binary_accuracy: 0.7295 - precision: 0.7297 - recall: 0.7170 - val_loss: 0.5138 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 42/100
# 144/144 [==============================] - 91s 629ms/step - loss: 0.5474 - binary_accuracy: 0.7298 - precision: 0.7241 - recall: 0.7133 - val_loss: 0.4733 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 43/100
# 144/144 [==============================] - 91s 630ms/step - loss: 0.5439 - binary_accuracy: 0.7252 - precision: 0.7279 - recall: 0.7064 - val_loss: 0.4725 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 44/100
# 144/144 [==============================] - 91s 633ms/step - loss: 0.5370 - binary_accuracy: 0.7325 - precision: 0.7383 - recall: 0.7226 - val_loss: 0.5189 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 45/100
# 144/144 [==============================] - 92s 636ms/step - loss: 0.5535 - binary_accuracy: 0.7258 - precision: 0.7286 - recall: 0.7044 - val_loss: 0.5978 - val_binary_accuracy: 0.6500 - val_precision: 0.3333 - val_recall: 0.7500
# Epoch 46/100
# 144/144 [==============================] - 92s 636ms/step - loss: 0.5414 - binary_accuracy: 0.7296 - precision: 0.7282 - recall: 0.7050 - val_loss: 0.5604 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 47/100
# 144/144 [==============================] - 92s 639ms/step - loss: 0.5453 - binary_accuracy: 0.7276 - precision: 0.7271 - recall: 0.7275 - val_loss: 0.3983 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 48/100
# 144/144 [==============================] - 92s 640ms/step - loss: 0.5509 - binary_accuracy: 0.7273 - precision: 0.7192 - recall: 0.7188 - val_loss: 0.5684 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 49/100
# 144/144 [==============================] - 93s 643ms/step - loss: 0.5353 - binary_accuracy: 0.7358 - precision: 0.7328 - recall: 0.7508 - val_loss: 0.3738 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 50/100
# 144/144 [==============================] - 93s 645ms/step - loss: 0.5334 - binary_accuracy: 0.7378 - precision: 0.7316 - recall: 0.7488 - val_loss: 0.4120 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 51/100
# 144/144 [==============================] - 93s 646ms/step - loss: 0.5368 - binary_accuracy: 0.7311 - precision: 0.7346 - recall: 0.7100 - val_loss: 0.5259 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 52/100
# 144/144 [==============================] - 93s 646ms/step - loss: 0.5409 - binary_accuracy: 0.7306 - precision: 0.7281 - recall: 0.7218 - val_loss: 0.3980 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 53/100
# 144/144 [==============================] - 93s 648ms/step - loss: 0.5452 - binary_accuracy: 0.7274 - precision: 0.7266 - recall: 0.7164 - val_loss: 0.4295 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 54/100
# 144/144 [==============================] - 94s 651ms/step - loss: 0.5351 - binary_accuracy: 0.7330 - precision: 0.7326 - recall: 0.7267 - val_loss: 0.4241 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 55/100
# 144/144 [==============================] - 94s 653ms/step - loss: 0.5399 - binary_accuracy: 0.7290 - precision: 0.7238 - recall: 0.7200 - val_loss: 0.4741 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 56/100
# 144/144 [==============================] - 94s 654ms/step - loss: 0.5288 - binary_accuracy: 0.7410 - precision: 0.7306 - recall: 0.7357 - val_loss: 0.4597 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 57/100
# 144/144 [==============================] - 94s 655ms/step - loss: 0.5397 - binary_accuracy: 0.7341 - precision: 0.7293 - recall: 0.7264 - val_loss: 0.4542 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 58/100
# 144/144 [==============================] - 95s 655ms/step - loss: 0.5491 - binary_accuracy: 0.7258 - precision: 0.7247 - recall: 0.7199 - val_loss: 0.4882 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 59/100
# 144/144 [==============================] - 95s 659ms/step - loss: 0.5277 - binary_accuracy: 0.7479 - precision: 0.7339 - recall: 0.7643 - val_loss: 0.4703 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 60/100
# 144/144 [==============================] - 95s 660ms/step - loss: 0.5421 - binary_accuracy: 0.7271 - precision: 0.7232 - recall: 0.7247 - val_loss: 0.4599 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 61/100
# 144/144 [==============================] - 96s 662ms/step - loss: 0.5283 - binary_accuracy: 0.7455 - precision: 0.7436 - recall: 0.7419 - val_loss: 0.4504 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 62/100
# 144/144 [==============================] - 96s 666ms/step - loss: 0.5379 - binary_accuracy: 0.7385 - precision: 0.7343 - recall: 0.7315 - val_loss: 0.4474 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 63/100
# 144/144 [==============================] - 96s 666ms/step - loss: 0.5337 - binary_accuracy: 0.7346 - precision: 0.7374 - recall: 0.7219 - val_loss: 0.4640 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 64/100
# 144/144 [==============================] - 96s 666ms/step - loss: 0.5295 - binary_accuracy: 0.7426 - precision: 0.7352 - recall: 0.7501 - val_loss: 0.5070 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 65/100
# 144/144 [==============================] - 96s 669ms/step - loss: 0.5328 - binary_accuracy: 0.7353 - precision: 0.7343 - recall: 0.7335 - val_loss: 0.4614 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 66/100
# 144/144 [==============================] - 97s 669ms/step - loss: 0.5343 - binary_accuracy: 0.7427 - precision: 0.7326 - recall: 0.7464 - val_loss: 0.4515 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 67/100
# 144/144 [==============================] - 97s 671ms/step - loss: 0.5268 - binary_accuracy: 0.7385 - precision: 0.7322 - recall: 0.7509 - val_loss: 0.4484 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 68/100
# 144/144 [==============================] - 97s 674ms/step - loss: 0.5359 - binary_accuracy: 0.7352 - precision: 0.7217 - recall: 0.7407 - val_loss: 0.4517 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 69/100
# 144/144 [==============================] - 97s 679ms/step - loss: 0.5261 - binary_accuracy: 0.7350 - precision: 0.7320 - recall: 0.7394 - val_loss: 0.3466 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 70/100
# 144/144 [==============================] - 98s 677ms/step - loss: 0.5265 - binary_accuracy: 0.7424 - precision: 0.7466 - recall: 0.7329 - val_loss: 0.4746 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 71/100
# 144/144 [==============================] - 98s 682ms/step - loss: 0.5378 - binary_accuracy: 0.7362 - precision: 0.7289 - recall: 0.7424 - val_loss: 0.5252 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 72/100
# 144/144 [==============================] - 98s 682ms/step - loss: 0.5312 - binary_accuracy: 0.7379 - precision: 0.7350 - recall: 0.7295 - val_loss: 0.4598 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 73/100
# 144/144 [==============================] - 99s 684ms/step - loss: 0.5341 - binary_accuracy: 0.7385 - precision: 0.7347 - recall: 0.7346 - val_loss: 0.4379 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 74/100
# 144/144 [==============================] - 99s 688ms/step - loss: 0.5328 - binary_accuracy: 0.7404 - precision: 0.7323 - recall: 0.7500 - val_loss: 0.4237 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 75/100
# 144/144 [==============================] - 100s 691ms/step - loss: 0.5287 - binary_accuracy: 0.7391 - precision: 0.7342 - recall: 0.7445 - val_loss: 0.5063 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 76/100
# 144/144 [==============================] - 100s 694ms/step - loss: 0.5351 - binary_accuracy: 0.7373 - precision: 0.7319 - recall: 0.7350 - val_loss: 0.4126 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 77/100
# 144/144 [==============================] - 100s 697ms/step - loss: 0.5291 - binary_accuracy: 0.7399 - precision: 0.7394 - recall: 0.7317 - val_loss: 0.3153 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 78/100
# 144/144 [==============================] - 104s 724ms/step - loss: 0.5293 - binary_accuracy: 0.7354 - precision: 0.7298 - recall: 0.7111 - val_loss: 0.3874 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 79/100
# 144/144 [==============================] - 101s 703ms/step - loss: 0.5300 - binary_accuracy: 0.7454 - precision: 0.7303 - recall: 0.7491 - val_loss: 0.3644 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 80/100
# 144/144 [==============================] - 102s 709ms/step - loss: 0.5285 - binary_accuracy: 0.7408 - precision: 0.7385 - recall: 0.7305 - val_loss: 0.3951 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 81/100
# 144/144 [==============================] - 102s 709ms/step - loss: 0.5296 - binary_accuracy: 0.7397 - precision: 0.7338 - recall: 0.7424 - val_loss: 0.3935 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 82/100
# 144/144 [==============================] - 102s 710ms/step - loss: 0.5203 - binary_accuracy: 0.7531 - precision: 0.7544 - recall: 0.7424 - val_loss: 0.5219 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 83/100
# 144/144 [==============================] - 103s 716ms/step - loss: 0.5281 - binary_accuracy: 0.7421 - precision: 0.7328 - recall: 0.7483 - val_loss: 0.4501 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 84/100
# 144/144 [==============================] - 104s 721ms/step - loss: 0.5274 - binary_accuracy: 0.7408 - precision: 0.7353 - recall: 0.7511 - val_loss: 0.3530 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 85/100
# 144/144 [==============================] - 104s 722ms/step - loss: 0.5209 - binary_accuracy: 0.7477 - precision: 0.7454 - recall: 0.7334 - val_loss: 0.4029 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 86/100
# 144/144 [==============================] - 104s 723ms/step - loss: 0.5259 - binary_accuracy: 0.7452 - precision: 0.7441 - recall: 0.7460 - val_loss: 0.3663 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 87/100
# 144/144 [==============================] - 105s 728ms/step - loss: 0.5347 - binary_accuracy: 0.7335 - precision: 0.7405 - recall: 0.7324 - val_loss: 0.3678 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 88/100
# 144/144 [==============================] - 105s 728ms/step - loss: 0.5249 - binary_accuracy: 0.7415 - precision: 0.7367 - recall: 0.7355 - val_loss: 0.3783 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 89/100
# 144/144 [==============================] - 106s 735ms/step - loss: 0.5213 - binary_accuracy: 0.7438 - precision: 0.7460 - recall: 0.7384 - val_loss: 0.3908 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 90/100
# 144/144 [==============================] - 106s 737ms/step - loss: 0.5247 - binary_accuracy: 0.7417 - precision: 0.7396 - recall: 0.7324 - val_loss: 0.4237 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 91/100
# 144/144 [==============================] - 106s 737ms/step - loss: 0.5305 - binary_accuracy: 0.7332 - precision: 0.7317 - recall: 0.7327 - val_loss: 0.3766 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 92/100
# 144/144 [==============================] - 107s 743ms/step - loss: 0.5227 - binary_accuracy: 0.7424 - precision: 0.7429 - recall: 0.7284 - val_loss: 0.4346 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 93/100
# 144/144 [==============================] - 107s 745ms/step - loss: 0.5271 - binary_accuracy: 0.7382 - precision: 0.7390 - recall: 0.7303 - val_loss: 0.3991 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 108s 747ms/step - loss: 0.5203 - binary_accuracy: 0.7457 - precision: 0.7388 - recall: 0.7407 - val_loss: 0.4205 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 108s 752ms/step - loss: 0.5245 - binary_accuracy: 0.7382 - precision: 0.7306 - recall: 0.7524 - val_loss: 0.5082 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 109s 753ms/step - loss: 0.5224 - binary_accuracy: 0.7472 - precision: 0.7388 - recall: 0.7630 - val_loss: 0.5129 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 110s 761ms/step - loss: 0.5304 - binary_accuracy: 0.7379 - precision: 0.7307 - recall: 0.7411 - val_loss: 0.3592 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 110s 765ms/step - loss: 0.5225 - binary_accuracy: 0.7388 - precision: 0.7334 - recall: 0.7526 - val_loss: 0.3942 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 111s 772ms/step - loss: 0.5208 - binary_accuracy: 0.7498 - precision: 0.7434 - recall: 0.7555 - val_loss: 0.3986 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 110s 767ms/step - loss: 0.5257 - binary_accuracy: 0.7466 - precision: 0.7489 - recall: 0.7408 - val_loss: 0.4157 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 19ms/step - loss: 0.4971 - binary_accuracy: 0.7703 - precision: 0.7409 - recall: 0.8117

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:21<00:00, 47.24it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.55it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.04it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.17it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 38.07it/s]
# 100%|██████████| 1000/1000 [00:23<00:00, 43.15it/s]
# 100%|██████████| 1000/1000 [00:22<00:00, 43.81it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.66it/s]
# 100%|██████████| 1000/1000 [00:22<00:00, 43.52it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
