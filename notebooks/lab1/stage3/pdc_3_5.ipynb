# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 99,760
# Trainable params: 99,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,230,193
# Trainable params: 2,230,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 89s 591ms/step - loss: 0.6930 - binary_accuracy: 0.5108 - precision: 0.5113 - recall: 0.3541 - val_loss: 0.6240 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 2/100
# 144/144 [==============================] - 85s 588ms/step - loss: 0.6468 - binary_accuracy: 0.6283 - precision: 0.6308 - recall: 0.5956 - val_loss: 0.5123 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 3/100
# 144/144 [==============================] - 86s 600ms/step - loss: 0.6002 - binary_accuracy: 0.6808 - precision: 0.6695 - recall: 0.6894 - val_loss: 0.5183 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 84s 579ms/step - loss: 0.5873 - binary_accuracy: 0.6960 - precision: 0.6999 - recall: 0.6922 - val_loss: 0.6233 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 5/100
# 144/144 [==============================] - 83s 577ms/step - loss: 0.5919 - binary_accuracy: 0.6944 - precision: 0.6993 - recall: 0.6549 - val_loss: 0.5417 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 84s 579ms/step - loss: 0.5828 - binary_accuracy: 0.6991 - precision: 0.6964 - recall: 0.7021 - val_loss: 0.4954 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 7/100
# 144/144 [==============================] - 84s 581ms/step - loss: 0.5918 - binary_accuracy: 0.6978 - precision: 0.6997 - recall: 0.6728 - val_loss: 0.5084 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 93/100
# 144/144 [==============================] - 95s 662ms/step - loss: 0.5200 - binary_accuracy: 0.7501 - precision: 0.7444 - recall: 0.7587 - val_loss: 0.4177 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 95s 659ms/step - loss: 0.5215 - binary_accuracy: 0.7443 - precision: 0.7419 - recall: 0.7474 - val_loss: 0.4287 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 96s 662ms/step - loss: 0.5314 - binary_accuracy: 0.7351 - precision: 0.7232 - recall: 0.7449 - val_loss: 0.4908 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 96s 665ms/step - loss: 0.5150 - binary_accuracy: 0.7513 - precision: 0.7380 - recall: 0.7581 - val_loss: 0.5333 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 96s 665ms/step - loss: 0.5317 - binary_accuracy: 0.7365 - precision: 0.7270 - recall: 0.7520 - val_loss: 0.3752 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 96s 664ms/step - loss: 0.5216 - binary_accuracy: 0.7447 - precision: 0.7405 - recall: 0.7436 - val_loss: 0.4172 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 96s 666ms/step - loss: 0.5366 - binary_accuracy: 0.7395 - precision: 0.7372 - recall: 0.7389 - val_loss: 0.3724 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 97s 669ms/step - loss: 0.5243 - binary_accuracy: 0.7427 - precision: 0.7414 - recall: 0.7391 - val_loss: 0.4815 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 15ms/step - loss: 0.5020 - binary_accuracy: 0.7657 - precision: 0.7289 - recall: 0.8252

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:17<00:00, 56.05it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 57.61it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 59.65it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 59.05it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 56.63it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 56.93it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 60.45it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 59.16it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 57.19it/s]
# 100%|██████████| 1000/1000 [00:18<00:00, 54.90it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
