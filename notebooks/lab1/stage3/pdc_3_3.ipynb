# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# =================================================================
# Total params: 25,904
# Trainable params: 25,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4194560
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 4,253,489
# Trainable params: 4,253,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 81s 546ms/step - loss: 0.7013 - binary_accuracy: 0.5107 - precision: 0.5069 - recall: 0.4963 - val_loss: 0.6049 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 144/144 [==============================] - 78s 544ms/step - loss: 0.6594 - binary_accuracy: 0.6164 - precision: 0.6229 - recall: 0.5741 - val_loss: 0.6712 - val_binary_accuracy: 0.5000 - val_precision: 0.2857 - val_recall: 1.0000
# Epoch 3/100
# 144/144 [==============================] - 79s 546ms/step - loss: 0.6216 - binary_accuracy: 0.6656 - precision: 0.6609 - recall: 0.6568 - val_loss: 0.5064 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 79s 546ms/step - loss: 0.6087 - binary_accuracy: 0.6780 - precision: 0.6671 - recall: 0.6688 - val_loss: 0.6188 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 5/100
# 144/144 [==============================] - 79s 545ms/step - loss: 0.5977 - binary_accuracy: 0.6921 - precision: 0.6871 - recall: 0.7080 - val_loss: 0.5579 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 79s 547ms/step - loss: 0.5932 - binary_accuracy: 0.6903 - precision: 0.6960 - recall: 0.6762 - val_loss: 0.4749 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 7/100
# 144/144 [==============================] - 79s 549ms/step - loss: 0.5782 - binary_accuracy: 0.7055 - precision: 0.7144 - recall: 0.6672 - val_loss: 0.4765 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 93/100
# 144/144 [==============================] - 103s 717ms/step - loss: 0.5347 - binary_accuracy: 0.7427 - precision: 0.7394 - recall: 0.7372 - val_loss: 0.4540 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 104s 722ms/step - loss: 0.5348 - binary_accuracy: 0.7412 - precision: 0.7332 - recall: 0.7471 - val_loss: 0.4248 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 95/100
# 144/144 [==============================] - 101s 703ms/step - loss: 0.5405 - binary_accuracy: 0.7307 - precision: 0.7262 - recall: 0.7351 - val_loss: 0.4692 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 98s 680ms/step - loss: 0.5406 - binary_accuracy: 0.7350 - precision: 0.7331 - recall: 0.7352 - val_loss: 0.4218 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 100s 692ms/step - loss: 0.5367 - binary_accuracy: 0.7443 - precision: 0.7326 - recall: 0.7526 - val_loss: 0.4305 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 108s 749ms/step - loss: 0.5362 - binary_accuracy: 0.7381 - precision: 0.7364 - recall: 0.7310 - val_loss: 0.4225 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 112s 775ms/step - loss: 0.5304 - binary_accuracy: 0.7410 - precision: 0.7362 - recall: 0.7372 - val_loss: 0.3731 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 100/100
# 144/144 [==============================] - 111s 771ms/step - loss: 0.5274 - binary_accuracy: 0.7463 - precision: 0.7476 - recall: 0.7453 - val_loss: 0.4298 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 16ms/step - loss: 0.5055 - binary_accuracy: 0.7643 - precision: 0.7444 - recall: 0.7852

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:21<00:00, 45.48it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 48.97it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 49.00it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 48.95it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 47.71it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 48.92it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 49.62it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 49.06it/s]
# 100%|██████████| 1000/1000 [00:20<00:00, 48.37it/s]
# 100%|██████████| 1000/1000 [00:21<00:00, 47.24it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
