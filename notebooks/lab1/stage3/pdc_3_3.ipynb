# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# =================================================================
# Total params: 25,904
# Trainable params: 25,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4194560
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 4,253,489
# Trainable params: 4,253,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 86s 575ms/step - loss: 0.6920 - binary_accuracy: 0.5211 - precision: 0.5247 - recall: 0.4822 - val_loss: 0.6049 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 2/100
# 144/144 [==============================] - 83s 578ms/step - loss: 0.6356 - binary_accuracy: 0.6411 - precision: 0.6409 - recall: 0.6305 - val_loss: 0.5341 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 3/100
# 144/144 [==============================] - 85s 590ms/step - loss: 0.6087 - binary_accuracy: 0.6781 - precision: 0.6806 - recall: 0.6513 - val_loss: 0.4420 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 4/100
# 144/144 [==============================] - 86s 598ms/step - loss: 0.5936 - binary_accuracy: 0.6989 - precision: 0.7005 - recall: 0.6767 - val_loss: 0.4576 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 5/100
# 144/144 [==============================] - 84s 580ms/step - loss: 0.5989 - binary_accuracy: 0.6916 - precision: 0.6938 - recall: 0.6733 - val_loss: 0.5651 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 84s 585ms/step - loss: 0.5870 - binary_accuracy: 0.7052 - precision: 0.7046 - recall: 0.6926 - val_loss: 0.5928 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 7/100
# 144/144 [==============================] - 85s 587ms/step - loss: 0.5841 - binary_accuracy: 0.6995 - precision: 0.6961 - recall: 0.7033 - val_loss: 0.5114 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 100s 693ms/step - loss: 0.5295 - binary_accuracy: 0.7450 - precision: 0.7440 - recall: 0.7408 - val_loss: 0.4713 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 101s 699ms/step - loss: 0.5405 - binary_accuracy: 0.7327 - precision: 0.7263 - recall: 0.7353 - val_loss: 0.4259 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 100s 695ms/step - loss: 0.5356 - binary_accuracy: 0.7304 - precision: 0.7281 - recall: 0.7180 - val_loss: 0.3532 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 101s 698ms/step - loss: 0.5487 - binary_accuracy: 0.7308 - precision: 0.7348 - recall: 0.7160 - val_loss: 0.4527 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 101s 700ms/step - loss: 0.5343 - binary_accuracy: 0.7415 - precision: 0.7400 - recall: 0.7381 - val_loss: 0.4169 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 101s 702ms/step - loss: 0.5373 - binary_accuracy: 0.7401 - precision: 0.7400 - recall: 0.7347 - val_loss: 0.4952 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 103s 712ms/step - loss: 0.5410 - binary_accuracy: 0.7308 - precision: 0.7279 - recall: 0.7338 - val_loss: 0.3636 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 15ms/step - loss: 0.4995 - binary_accuracy: 0.7587 - precision: 0.7587 - recall: 0.7392

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:15<00:00, 64.87it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 58.53it/s]
# 100%|██████████| 1000/1000 [00:18<00:00, 53.42it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 58.28it/s]
# 100%|██████████| 1000/1000 [00:19<00:00, 52.42it/s]
# 100%|██████████| 1000/1000 [00:19<00:00, 52.52it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 56.35it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 58.66it/s]
# 100%|██████████| 1000/1000 [00:18<00:00, 55.55it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 56.53it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
