# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=16, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=64, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# =================================================================
# Total params: 25,904
# Trainable params: 25,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4194560
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 4,253,489
# Trainable params: 4,253,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 33s 146ms/step - loss: 0.5747 - binary_accuracy: 0.6718 - precision: 0.6888 - recall: 0.8175 - val_loss: 0.6449 - val_binary_accuracy: 0.6250 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 2/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3965 - binary_accuracy: 0.8384 - precision: 0.8884 - recall: 0.8163 - val_loss: 0.5915 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 3/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3907 - binary_accuracy: 0.8495 - precision: 0.8907 - recall: 0.8453 - val_loss: 0.5112 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 4/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3561 - binary_accuracy: 0.8582 - precision: 0.9156 - recall: 0.8303 - val_loss: 0.4817 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 5/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3400 - binary_accuracy: 0.8795 - precision: 0.9280 - recall: 0.8613 - val_loss: 0.5519 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 6/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3395 - binary_accuracy: 0.8665 - precision: 0.9211 - recall: 0.8451 - val_loss: 0.4522 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 7/50
# 205/205 [==============================] - 29s 141ms/step - loss: 0.3193 - binary_accuracy: 0.8818 - precision: 0.9289 - recall: 0.8604 - val_loss: 0.4701 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 8/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.3176 - binary_accuracy: 0.8848 - precision: 0.9286 - recall: 0.8672 - val_loss: 1.1044 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 9/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.3016 - binary_accuracy: 0.8866 - precision: 0.9236 - recall: 0.8810 - val_loss: 0.4700 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 10/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.3105 - binary_accuracy: 0.8879 - precision: 0.9319 - recall: 0.8759 - val_loss: 0.4931 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 11/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2763 - binary_accuracy: 0.8853 - precision: 0.9256 - recall: 0.8757 - val_loss: 0.3654 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 12/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2947 - binary_accuracy: 0.8873 - precision: 0.9334 - recall: 0.8688 - val_loss: 0.7388 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 13/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.3016 - binary_accuracy: 0.8867 - precision: 0.9192 - recall: 0.8894 - val_loss: 0.5294 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 14/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2741 - binary_accuracy: 0.8990 - precision: 0.9464 - recall: 0.8796 - val_loss: 0.3685 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 15/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2488 - binary_accuracy: 0.9031 - precision: 0.9396 - recall: 0.8925 - val_loss: 0.5133 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 16/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2689 - binary_accuracy: 0.8936 - precision: 0.9276 - recall: 0.8876 - val_loss: 0.4857 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 17/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2791 - binary_accuracy: 0.8936 - precision: 0.9311 - recall: 0.8803 - val_loss: 0.5612 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 18/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2673 - binary_accuracy: 0.8950 - precision: 0.9246 - recall: 0.8951 - val_loss: 0.4447 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 19/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2577 - binary_accuracy: 0.9027 - precision: 0.9362 - recall: 0.8937 - val_loss: 0.8402 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 20/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2572 - binary_accuracy: 0.9036 - precision: 0.9286 - recall: 0.9056 - val_loss: 0.4691 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 21/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2483 - binary_accuracy: 0.9095 - precision: 0.9473 - recall: 0.8966 - val_loss: 0.6472 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 22/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2206 - binary_accuracy: 0.9097 - precision: 0.9372 - recall: 0.9100 - val_loss: 0.6966 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 23/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2614 - binary_accuracy: 0.8921 - precision: 0.9118 - recall: 0.9079 - val_loss: 0.3597 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 24/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2275 - binary_accuracy: 0.9093 - precision: 0.9392 - recall: 0.9040 - val_loss: 0.4811 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 25/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2596 - binary_accuracy: 0.9012 - precision: 0.9275 - recall: 0.9037 - val_loss: 0.3900 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 26/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2347 - binary_accuracy: 0.9053 - precision: 0.9354 - recall: 0.9007 - val_loss: 0.4734 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 27/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2328 - binary_accuracy: 0.9124 - precision: 0.9474 - recall: 0.9042 - val_loss: 0.6926 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 28/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2491 - binary_accuracy: 0.9072 - precision: 0.9316 - recall: 0.9120 - val_loss: 0.8468 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 29/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2375 - binary_accuracy: 0.9094 - precision: 0.9259 - recall: 0.9204 - val_loss: 0.5529 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 30/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2278 - binary_accuracy: 0.9087 - precision: 0.9373 - recall: 0.9076 - val_loss: 0.3851 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 31/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2510 - binary_accuracy: 0.9088 - precision: 0.9290 - recall: 0.9141 - val_loss: 0.4710 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 32/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1992 - binary_accuracy: 0.9246 - precision: 0.9516 - recall: 0.9207 - val_loss: 0.4198 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 33/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2071 - binary_accuracy: 0.9242 - precision: 0.9436 - recall: 0.9249 - val_loss: 0.4339 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 34/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2258 - binary_accuracy: 0.9185 - precision: 0.9433 - recall: 0.9121 - val_loss: 0.3874 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 35/50
# 205/205 [==============================] - ETA: 0s - loss: 0.2034 - binary_accuracy: 0.9250 - precision: 0.9479 - recall: 0.92 - 30s 147ms/step - loss: 0.2035 - binary_accuracy: 0.9250 - precision: 0.9478 - recall: 0.9252 - val_loss: 0.9019 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 36/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2201 - binary_accuracy: 0.9113 - precision: 0.9368 - recall: 0.9121 - val_loss: 0.4700 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 37/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2080 - binary_accuracy: 0.9285 - precision: 0.9558 - recall: 0.9208 - val_loss: 0.3222 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 38/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1717 - binary_accuracy: 0.9375 - precision: 0.9552 - recall: 0.9395 - val_loss: 0.3303 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 39/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1783 - binary_accuracy: 0.9327 - precision: 0.9538 - recall: 0.9298 - val_loss: 0.4392 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 40/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2059 - binary_accuracy: 0.9247 - precision: 0.9477 - recall: 0.9241 - val_loss: 0.3715 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 41/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1912 - binary_accuracy: 0.9283 - precision: 0.9504 - recall: 0.9260 - val_loss: 0.3686 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 42/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1911 - binary_accuracy: 0.9275 - precision: 0.9512 - recall: 0.9263 - val_loss: 0.4503 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 43/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1823 - binary_accuracy: 0.9327 - precision: 0.9591 - recall: 0.9258 - val_loss: 0.4147 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 44/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.2028 - binary_accuracy: 0.9249 - precision: 0.9469 - recall: 0.9241 - val_loss: 0.2462 - val_binary_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 45/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.2098 - binary_accuracy: 0.9186 - precision: 0.9396 - recall: 0.9173 - val_loss: 0.4511 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 46/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1754 - binary_accuracy: 0.9306 - precision: 0.9440 - recall: 0.9358 - val_loss: 0.3626 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 47/50
# 205/205 [==============================] - 31s 150ms/step - loss: 0.1802 - binary_accuracy: 0.9283 - precision: 0.9510 - recall: 0.9270 - val_loss: 0.5924 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 48/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1777 - binary_accuracy: 0.9361 - precision: 0.9542 - recall: 0.9379 - val_loss: 0.6973 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 49/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1869 - binary_accuracy: 0.9325 - precision: 0.9563 - recall: 0.9270 - val_loss: 0.3726 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 50/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1893 - binary_accuracy: 0.9287 - precision: 0.9539 - recall: 0.9259 - val_loss: 0.5486 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 10ms/step - loss: 0.2761 - binary_accuracy: 0.8942 - precision: 0.8821 - recall: 0.9590

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 134.71it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 138.28it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 115.07it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.67it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.06it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 121.36it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 135.91it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 125.47it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 123.99it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 116.34it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())
