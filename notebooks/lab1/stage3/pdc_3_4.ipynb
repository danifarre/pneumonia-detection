# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 190,608
# Trainable params: 190,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,321,041
# Trainable params: 2,321,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 87s 576ms/step - loss: 0.6947 - binary_accuracy: 0.5094 - precision: 0.4765 - recall: 0.2503 - val_loss: 0.7237 - val_binary_accuracy: 0.2000 - val_precision: 0.2000 - val_recall: 1.0000
# Epoch 2/100
# 144/144 [==============================] - 83s 574ms/step - loss: 0.6940 - binary_accuracy: 0.5046 - precision: 0.4989 - recall: 0.7012 - val_loss: 0.6690 - val_binary_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 144/144 [==============================] - 82s 569ms/step - loss: 0.6734 - binary_accuracy: 0.5838 - precision: 0.5839 - recall: 0.5523 - val_loss: 0.4780 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 4/100
# 144/144 [==============================] - 82s 572ms/step - loss: 0.6228 - binary_accuracy: 0.6683 - precision: 0.6556 - recall: 0.6791 - val_loss: 0.6100 - val_binary_accuracy: 0.6000 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 5/100
# 144/144 [==============================] - 83s 573ms/step - loss: 0.5947 - binary_accuracy: 0.6934 - precision: 0.6907 - recall: 0.6916 - val_loss: 0.4692 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 6/100
# 144/144 [==============================] - 82s 571ms/step - loss: 0.5912 - binary_accuracy: 0.6916 - precision: 0.6917 - recall: 0.6821 - val_loss: 0.5076 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 91s 634ms/step - loss: 0.5207 - binary_accuracy: 0.7432 - precision: 0.7336 - recall: 0.7517 - val_loss: 0.4446 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 91s 632ms/step - loss: 0.5395 - binary_accuracy: 0.7308 - precision: 0.7237 - recall: 0.7280 - val_loss: 0.3619 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 96/100
# 144/144 [==============================] - 91s 634ms/step - loss: 0.5304 - binary_accuracy: 0.7390 - precision: 0.7352 - recall: 0.7333 - val_loss: 0.3899 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 91s 634ms/step - loss: 0.5306 - binary_accuracy: 0.7399 - precision: 0.7297 - recall: 0.7390 - val_loss: 0.3939 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 92s 635ms/step - loss: 0.5386 - binary_accuracy: 0.7326 - precision: 0.7391 - recall: 0.7165 - val_loss: 0.3924 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 92s 635ms/step - loss: 0.5276 - binary_accuracy: 0.7351 - precision: 0.7307 - recall: 0.7279 - val_loss: 0.4401 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 92s 638ms/step - loss: 0.5281 - binary_accuracy: 0.7393 - precision: 0.7268 - recall: 0.7536 - val_loss: 0.3377 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 13ms/step - loss: 0.5051 - binary_accuracy: 0.7584 - precision: 0.7667 - recall: 0.7236

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:09<00:00, 100.09it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 84.28it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 85.02it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 89.74it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 87.01it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 85.49it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 90.13it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 89.22it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 85.84it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 89.09it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
