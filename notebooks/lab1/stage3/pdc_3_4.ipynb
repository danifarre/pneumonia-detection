# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=128, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# =================================================================
# Total params: 190,608
# Trainable params: 190,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,321,041
# Trainable params: 2,321,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=64),
					validation_data=(x_val, y_val),
					epochs=100)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 88s 584ms/step - loss: 0.6948 - binary_accuracy: 0.5048 - precision: 0.5046 - recall: 0.5783 - val_loss: 0.7192 - val_binary_accuracy: 0.2500 - val_precision: 0.2105 - val_recall: 1.0000
# Epoch 2/100
# 144/144 [==============================] - 83s 573ms/step - loss: 0.6901 - binary_accuracy: 0.5310 - precision: 0.5254 - recall: 0.5473 - val_loss: 0.7215 - val_binary_accuracy: 0.3000 - val_precision: 0.2222 - val_recall: 1.0000
# Epoch 3/100
# 144/144 [==============================] - 83s 573ms/step - loss: 0.6852 - binary_accuracy: 0.5657 - precision: 0.5678 - recall: 0.5332 - val_loss: 0.6613 - val_binary_accuracy: 0.6500 - val_precision: 0.3333 - val_recall: 0.7500
# Epoch 4/100
# 144/144 [==============================] - 84s 584ms/step - loss: 0.6754 - binary_accuracy: 0.5796 - precision: 0.5793 - recall: 0.5585 - val_loss: 0.8029 - val_binary_accuracy: 0.6500 - val_precision: 0.3333 - val_recall: 0.7500
# Epoch 5/100
# 144/144 [==============================] - 84s 582ms/step - loss: 0.6650 - binary_accuracy: 0.6072 - precision: 0.5953 - recall: 0.6365 - val_loss: 0.7887 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 6/100
# 144/144 [==============================] - 84s 580ms/step - loss: 0.6601 - binary_accuracy: 0.6101 - precision: 0.6078 - recall: 0.5920 - val_loss: 0.5489 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch
- val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 91/100
# 144/144 [==============================] - 94s 654ms/step - loss: 0.5488 - binary_accuracy: 0.7256 - precision: 0.7267 - recall: 0.7078 - val_loss: 0.3985 - val_binary_accuracy: 0.9500 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 92/100
# 144/144 [==============================] - 95s 657ms/step - loss: 0.5424 - binary_accuracy: 0.7331 - precision: 0.7322 - recall: 0.7289 - val_loss: 0.3870 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 93/100
# 144/144 [==============================] - 95s 659ms/step - loss: 0.5538 - binary_accuracy: 0.7226 - precision: 0.7253 - recall: 0.7103 - val_loss: 0.4775 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 94/100
# 144/144 [==============================] - 95s 656ms/step - loss: 0.5433 - binary_accuracy: 0.7313 - precision: 0.7243 - recall: 0.7342 - val_loss: 0.4425 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 95/100
# 144/144 [==============================] - 95s 658ms/step - loss: 0.5386 - binary_accuracy: 0.7385 - precision: 0.7418 - recall: 0.7257 - val_loss: 0.4275 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 96/100
# 144/144 [==============================] - 95s 659ms/step - loss: 0.5439 - binary_accuracy: 0.7346 - precision: 0.7388 - recall: 0.7100 - val_loss: 0.4762 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 97/100
# 144/144 [==============================] - 95s 660ms/step - loss: 0.5501 - binary_accuracy: 0.7230 - precision: 0.7270 - recall: 0.7032 - val_loss: 0.4451 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 98/100
# 144/144 [==============================] - 96s 665ms/step - loss: 0.5423 - binary_accuracy: 0.7379 - precision: 0.7307 - recall: 0.7253 - val_loss: 0.4126 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 99/100
# 144/144 [==============================] - 96s 664ms/step - loss: 0.5539 - binary_accuracy: 0.7277 - precision: 0.7277 - recall: 0.7041 - val_loss: 0.3535 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 100/100
# 144/144 [==============================] - 96s 667ms/step - loss: 0.5463 - binary_accuracy: 0.7297 - precision: 0.7378 - recall: 0.7146 - val_loss: 0.4194 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 2s 14ms/step - loss: 0.5167 - binary_accuracy: 0.7561 - precision: 0.7503 - recall: 0.7473

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:14<00:00, 67.50it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 62.60it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 66.25it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 65.51it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 62.39it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 64.12it/s]
# 100%|██████████| 1000/1000 [00:14<00:00, 66.91it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 65.65it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 62.27it/s]
# 100%|██████████| 1000/1000 [00:16<00:00, 61.23it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())
