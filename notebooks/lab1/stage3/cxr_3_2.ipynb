# %% [markdown]
# # Imports

# %%
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
model = models.Sequential()

model.add(layers.Conv2D(filters=8, activation='relu', kernel_size=3, padding='same', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=8, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, activation="relu", kernel_size=3, padding="same"))
model.add(layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# =================================================================
# Total params: 6,616
# Trainable params: 6,616
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,137,049
# Trainable params: 2,137,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 33s 150ms/step - loss: 0.5938 - binary_accuracy: 0.6573 - precision: 0.6845 - recall: 0.7890 - val_loss: 0.6257 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 2/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.4052 - binary_accuracy: 0.8255 - precision: 0.8909 - recall: 0.8020 - val_loss: 0.6654 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 3/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.3606 - binary_accuracy: 0.8615 - precision: 0.9055 - recall: 0.8541 - val_loss: 0.4306 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 4/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.3346 - binary_accuracy: 0.8738 - precision: 0.9166 - recall: 0.8664 - val_loss: 0.7546 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 5/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.3090 - binary_accuracy: 0.8833 - precision: 0.9248 - recall: 0.8709 - val_loss: 0.7714 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 6/50
# 205/205 [==============================] - ETA: 0s - loss: 0.3356 - binary_accuracy: 0.8757 - precision: 0.9259 - recall: 0.85 - 30s 146ms/step - loss: 0.3355 - binary_accuracy: 0.8757 - precision: 0.9259 - recall: 0.8567 - val_loss: 0.6304 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 7/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2836 - binary_accuracy: 0.8850 - precision: 0.9259 - recall: 0.8810 - val_loss: 0.8074 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 8/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2937 - binary_accuracy: 0.8850 - precision: 0.9282 - recall: 0.8775 - val_loss: 0.4638 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 9/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2958 - binary_accuracy: 0.8842 - precision: 0.9309 - recall: 0.8704 - val_loss: 0.3773 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 10/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2658 - binary_accuracy: 0.8950 - precision: 0.9399 - recall: 0.8764 - val_loss: 0.4424 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 11/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2708 - binary_accuracy: 0.8974 - precision: 0.9375 - recall: 0.8843 - val_loss: 0.8626 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 12/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2725 - binary_accuracy: 0.8930 - precision: 0.9341 - recall: 0.8791 - val_loss: 0.8391 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 13/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2833 - binary_accuracy: 0.8917 - precision: 0.9379 - recall: 0.8726 - val_loss: 0.8259 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 14/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2761 - binary_accuracy: 0.8875 - precision: 0.9176 - recall: 0.8882 - val_loss: 0.5099 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 15/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2725 - binary_accuracy: 0.8903 - precision: 0.9326 - recall: 0.8715 - val_loss: 0.5744 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 16/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2660 - binary_accuracy: 0.8941 - precision: 0.9416 - recall: 0.8717 - val_loss: 1.4786 - val_binary_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 17/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2392 - binary_accuracy: 0.9073 - precision: 0.9405 - recall: 0.9001 - val_loss: 0.5182 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 18/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2699 - binary_accuracy: 0.8946 - precision: 0.9315 - recall: 0.8860 - val_loss: 0.6006 - val_binary_accuracy: 0.6250 - val_precision: 0.5833 - val_recall: 0.8750
# Epoch 19/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2387 - binary_accuracy: 0.9069 - precision: 0.9402 - recall: 0.9037 - val_loss: 0.3870 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 20/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2473 - binary_accuracy: 0.9048 - precision: 0.9394 - recall: 0.8935 - val_loss: 0.5669 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 21/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2336 - binary_accuracy: 0.9067 - precision: 0.9414 - recall: 0.9016 - val_loss: 0.7242 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 22/50
# 205/205 [==============================] - 30s 144ms/step - loss: 0.2457 - binary_accuracy: 0.8954 - precision: 0.9287 - recall: 0.8962 - val_loss: 0.5818 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 23/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2500 - binary_accuracy: 0.9107 - precision: 0.9466 - recall: 0.9004 - val_loss: 0.5588 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 24/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2151 - binary_accuracy: 0.9098 - precision: 0.9285 - recall: 0.9153 - val_loss: 1.0468 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 25/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2387 - binary_accuracy: 0.9008 - precision: 0.9269 - recall: 0.9065 - val_loss: 0.8685 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 26/50
# 205/205 [==============================] - 30s 145ms/step - loss: 0.2287 - binary_accuracy: 0.9119 - precision: 0.9433 - recall: 0.9034 - val_loss: 1.0578 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 27/50
# 205/205 [==============================] - ETA: 0s - loss: 0.2127 - binary_accuracy: 0.9150 - precision: 0.9452 - recall: 0.90 - 30s 145ms/step - loss: 0.2127 - binary_accuracy: 0.9151 - precision: 0.9452 - recall: 0.9099 - val_loss: 0.7942 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 28/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2245 - binary_accuracy: 0.9096 - precision: 0.9422 - recall: 0.9022 - val_loss: 0.4005 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 29/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2105 - binary_accuracy: 0.9164 - precision: 0.9519 - recall: 0.9031 - val_loss: 0.3643 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 30/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2330 - binary_accuracy: 0.9077 - precision: 0.9378 - recall: 0.9028 - val_loss: 0.7062 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 31/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2078 - binary_accuracy: 0.9199 - precision: 0.9469 - recall: 0.9159 - val_loss: 0.5323 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 32/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1831 - binary_accuracy: 0.9318 - precision: 0.9520 - recall: 0.9309 - val_loss: 1.1731 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 33/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2161 - binary_accuracy: 0.9301 - precision: 0.9549 - recall: 0.9223 - val_loss: 0.3776 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 34/50
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1988 - binary_accuracy: 0.9224 - precision: 0.9460 - recall: 0.9197 - val_loss: 0.2526 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.8750
# Epoch 35/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2141 - binary_accuracy: 0.9161 - precision: 0.9447 - recall: 0.9141 - val_loss: 0.4221 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 36/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2217 - binary_accuracy: 0.9120 - precision: 0.9443 - recall: 0.9063 - val_loss: 0.6049 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 37/50
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1898 - binary_accuracy: 0.9285 - precision: 0.9515 - recall: 0.9278 - val_loss: 0.8158 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 38/50
# 205/205 [==============================] - ETA: 0s - loss: 0.1967 - binary_accuracy: 0.9224 - precision: 0.9491 - recall: 0.91 - 30s 148ms/step - loss: 0.1967 - binary_accuracy: 0.9224 - precision: 0.9491 - recall: 0.9184 - val_loss: 0.9592 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 39/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.2067 - binary_accuracy: 0.9191 - precision: 0.9481 - recall: 0.9125 - val_loss: 0.5433 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 40/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1838 - binary_accuracy: 0.9323 - precision: 0.9572 - recall: 0.9272 - val_loss: 0.2548 - val_binary_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 0.8750
# Epoch 41/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1631 - binary_accuracy: 0.9382 - precision: 0.9623 - recall: 0.9332 - val_loss: 0.5668 - val_binary_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 42/50
# 205/205 [==============================] - 30s 148ms/step - loss: 0.1844 - binary_accuracy: 0.9306 - precision: 0.9585 - recall: 0.9257 - val_loss: 0.7052 - val_binary_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 43/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1868 - binary_accuracy: 0.9308 - precision: 0.9514 - recall: 0.9330 - val_loss: 0.4624 - val_binary_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 44/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.2025 - binary_accuracy: 0.9245 - precision: 0.9550 - recall: 0.9189 - val_loss: 0.4203 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 45/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1798 - binary_accuracy: 0.9322 - precision: 0.9512 - recall: 0.9309 - val_loss: 0.5084 - val_binary_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 46/50
# 205/205 [==============================] - 31s 149ms/step - loss: 0.1896 - binary_accuracy: 0.9330 - precision: 0.9547 - recall: 0.9297 - val_loss: 0.4934 - val_binary_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 47/50
# 205/205 [==============================] - 31s 150ms/step - loss: 0.1952 - binary_accuracy: 0.9222 - precision: 0.9471 - recall: 0.9188 - val_loss: 0.3041 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 48/50
# 205/205 [==============================] - 31s 150ms/step - loss: 0.2072 - binary_accuracy: 0.9189 - precision: 0.9497 - recall: 0.9114 - val_loss: 0.3607 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 49/50
# 205/205 [==============================] - 31s 151ms/step - loss: 0.1720 - binary_accuracy: 0.9358 - precision: 0.9607 - recall: 0.9275 - val_loss: 0.4217 - val_binary_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 50/50
# 205/205 [==============================] - 31s 151ms/step - loss: 0.1788 - binary_accuracy: 0.9331 - precision: 0.9514 - recall: 0.9342 - val_loss: 0.6736 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 10ms/step - loss: 0.3008 - binary_accuracy: 0.8942 - precision: 0.8699 - recall: 0.9769

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 133.47it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 120.60it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 116.12it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.66it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.25it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 123.55it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 129.99it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 127.09it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.03it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 117.99it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())
