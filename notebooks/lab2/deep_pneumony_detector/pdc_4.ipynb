# %% [markdown]
# # Imports

# %%
import datetime
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv1D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv1D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])

    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])

    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),

        tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),

        conv_block(64),
        conv_block(128),
        conv_block(256),
        conv_block(256),

        tf.keras.layers.Flatten(),
        dense_block(516, 0.2),
        dense_block(256, 0.2),
        dense_block(128, 0.2),
        dense_block(64, 0.2),

        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 64)      0
# _________________________________________________________________
# sequential (Sequential)      (None, 64, 64, 128)       123776
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 32, 32, 256)       493312
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 16, 16, 512)       1969664
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 8, 8, 512)         2362880
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 516)               16910868
# _________________________________________________________________
# sequential_5 (Sequential)    (None, 256)               133376
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 128)               33408
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 64)                8512
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 22,074,581
# Trainable params: 22,069,837
# Non-trainable params: 4,744
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 574/574 [==============================] - 117s 194ms/step - loss: 0.7661 - binary_accuracy: 0.5633 - precision: 0.5577 - recall: 0.5733 - val_loss: 0.6209 - val_binary_accuracy: 0.6500 - val_precision: 0.2857 - val_recall: 0.5000
# Epoch 2/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.6420 - binary_accuracy: 0.6485 - precision: 0.6454 - recall: 0.6474 - val_loss: 0.6006 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000TA: 5s - loss: 0.6427 - bi - ETA: 0s - loss: 0.6421 - binary_accuracy: 0.6484 - precision: 0.6453 - recall:
# Epoch 3/50
# 574/574 [==============================] - 108s 189ms/step - loss: 0.6181 - binary_accuracy: 0.6649 - precision: 0.6626 - recall: 0.6524 - val_loss: 0.4837 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.25000.6594 - precisi - ETA: 41s - loss: 0.6206 - binary_accuracy: 0.6598 - pre - ETA: 35s - loss: 0.
# Epoch 4/50
# 574/574 [==============================] - 108s 188ms/step - loss: 0.6172 - binary_accuracy: 0.6708 - precision: 0.6714 - recall: 0.6608 - val_loss: 0.4221 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500ccuracy: 0.6702 - precision: 0.6711 -  - ETA: 5s - loss: 0.6176
# Epoch 5/50
# 574/574 [==============================] - 109s 190ms/step - loss: 0.5992 - binary_accuracy: 0.6935 - precision: 0.6936 - recall: 0.6998 - val_loss: 0.5886 - val_binary_accuracy: 0.7000 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 6/50
# 574/574 [==============================] - 110s 191ms/step - loss: 0.6002 - binary_accuracy: 0.6903 - precision: 0.6825 - recall: 0.6950 - val_loss: 0.5149 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000 loss: 0.6016 - binary_accuracy: 0.6898 - precision: 0.6811 - recall: 0 - ETA: 16s - loss: 0.6015 - bina - E
# Epoch 7/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5922 - binary_accuracy: 0.6908 - precision: 0.6866 - recall: 0.6721 - val_loss: 0.7137 - val_binary_accuracy: 0.6000 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 8/50
# 574/574 [==============================] - 106s 184ms/step - loss: 0.5923 - binary_accuracy: 0.6976 - precision: 0.6863 - recall: 0.7020 - val_loss: 0.5162 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 9/50
# 574/574 [==============================] - 105s 183ms/step - loss: 0.5841 - binary_accuracy: 0.6976 - precision: 0.6857 - recall: 0.6978 - val_loss: 0.4536 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 10/50
# 574/574 [==============================] - 105s 183ms/step - loss: 0.5942 - binary_accuracy: 0.6875 - precision: 0.6770 - recall: 0.7301 - val_loss: 0.5064 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 11/50
# 574/574 [==============================] - 105s 183ms/step - loss: 0.5864 - binary_accuracy: 0.7017 - precision: 0.6936 - recall: 0.7093 - val_loss: 0.3848 - val_binary_accuracy: 0.8500 - val_precision: 1.0000 - val_recall: 0.2500ccur
# Epoch 12/50
# 574/574 [==============================] - 105s 183ms/step - loss: 0.5851 - binary_accuracy: 0.6980 - precision: 0.6965 - recall: 0.6894 - val_loss: 0.6482 - val_binary_accuracy: 0.5500 - val_precision: 0.3077 - val_recall: 1.0000
# Epoch 13/50
# 574/574 [==============================] - 107s 186ms/step - loss: 0.5822 - binary_accuracy: 0.6988 - precision: 0.6968 - recall: 0.6963 - val_loss: 0.7221 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000- loss: 0.5827 - binary_accuracy: 0.6979 - precision: 0.6982 -  - ETA: 35s - loss:
# Epoch 14/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5776 - binary_accuracy: 0.7071 - precision: 0.6960 - recall: 0.7239 - val_loss: 0.4983 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 15/50
# 574/574 [==============================] - 108s 188ms/step - loss: 0.5726 - binary_accuracy: 0.7168 - precision: 0.7301 - recall: 0.6988 - val_loss: 0.3061 - val_binary_accuracy: 0.9000 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 16/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5696 - binary_accuracy: 0.7059 - precision: 0.7003 - recall: 0.7001 - val_loss: 0.5858 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 17/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5656 - binary_accuracy: 0.7105 - precision: 0.7040 - recall: 0.7099 - val_loss: 0.8450 - val_binary_accuracy: 0.5000 - val_precision: 0.2857 - val_recall: 1.0000
# Epoch 18/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5655 - binary_accuracy: 0.7193 - precision: 0.7228 - recall: 0.7109 - val_loss: 0.3919 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500n - ETA: 12s - loss: 0.5643 - binary_accuracy: 0.7 - ETA
# Epoch 19/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5736 - binary_accuracy: 0.7080 - precision: 0.7088 - recall: 0.7059 - val_loss: 0.7934 - val_binary_accuracy: 0.3500 - val_precision: 0.2353 - val_recall: 1.0000- l
# Epoch 20/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5765 - binary_accuracy: 0.7124 - precision: 0.7172 - recall: 0.6971 - val_loss: 0.5371 - val_binary_accuracy: 0.6000 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 21/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5674 - binary_accuracy: 0.7162 - precision: 0.7077 - recall: 0.7232 - val_loss: 0.4193 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000.5653 - binary_ - ETA: 5s - loss: 0.567
# Epoch 22/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5662 - binary_accuracy: 0.7188 - precision: 0.7140 - recall: 0.7235 - val_loss: 0.6096 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 23/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5715 - binary_accuracy: 0.7154 - precision: 0.7233 - recall: 0.6844 - val_loss: 0.2717 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 24/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5717 - binary_accuracy: 0.7125 - precision: 0.7152 - recall: 0.6987 - val_loss: 0.7988 - val_binary_accuracy: 0.5000 - val_precision: 0.2857 - val_recall: 1.0000
# Epoch 25/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5641 - binary_accuracy: 0.7151 - precision: 0.7224 - recall: 0.6847 - val_loss: 0.3136 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 26/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5552 - binary_accuracy: 0.7221 - precision: 0.7232 - recall: 0.7174 - val_loss: 0.6466 - val_binary_accuracy: 0.5000 - val_precision: 0.2857 - val_recall: 1.0000nary_accuracy: 0.7260 - precision: 0.7295 - recall: 0.718 - ETA: 33s - loss: 0.5510 - bi
# Epoch 27/50
# 574/574 [==============================] - 108s 188ms/step - loss: 0.5691 - binary_accuracy: 0.7125 - precision: 0.7069 - recall: 0.7238 - val_loss: 0.4840 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 28/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5611 - binary_accuracy: 0.7170 - precision: 0.7216 - recall: 0.7116 - val_loss: 0.4227 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000: 3s - loss: 0.5611 - binary_accuracy: 0.7169 - precision: 0.721 - ETA: 1s - loss: 0.5611 - binary_accuracy: 0.7169 - precision: 0.721
# Epoch 29/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5629 - binary_accuracy: 0.7103 - precision: 0.7055 - recall: 0.7165 - val_loss: 0.4473 - val_binary_accuracy: 0.7000 - val_precision: 0.3750 - val_recall: 0.7500
# Epoch 30/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.
50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5534 - binary_accuracy: 0.7188 - precision: 0.7202 - recall: 0.7094 - val_loss: 0.4666 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 46/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5437 - binary_accuracy: 0.7316 - precision: 0.7230 - recall: 0.7387 - val_loss: 0.4536 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 47/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5471 - binary_accuracy: 0.7253 - precision: 0.7273 - recall: 0.7070 - val_loss: 0.7101 - val_binary_accuracy: 0.5500 - val_precision: 0.3077 - val_recall: 1.0000
# Epoch 48/50
# 574/574 [==============================] - 107s 187ms/step - loss: 0.5448 - binary_accuracy: 0.7315 - precision: 0.7295 - recall: 0.7309 - val_loss: 0.4998 - val_binary_accuracy: 0.7500 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 49/50
# 574/574 [==============================] - 108s 187ms/step - loss: 0.5344 - binary_accuracy: 0.7444 - precision: 0.7392 - recall: 0.7546 - val_loss: 0.3352 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 50/50
# 574/574 [==============================] - 108s 188ms/step - loss: 0.5421 - binary_accuracy: 0.7325 - precision: 0.7327 - recall: 0.7394 - val_loss: 0.3798 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %%
time = str(datetime.datetime.now().strftime("%d%m%Y%H%M%S"))

model_json = model.to_json()
with open("models/" + "pdc_" + time + ".json", "w") as json_file:
    json_file.write(model_json)

model.save_weights("models/" + "pdc_" + time + ".h5")
print("pdc_" + time)
# Out:
# pdc_16022022213038

# %% [markdown]
# # Evaluating the model

# %% [markdown]
# ### Pneumonia Detection Challenge

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 15s 140ms/step - loss: 0.5096 - binary_accuracy: 0.7548 - precision: 0.7802 - recall: 0.6904

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:10<00:00, 99.57it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 104.69it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 107.81it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 110.28it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 108.05it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 106.95it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 111.06it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 111.31it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 106.98it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 108.89it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())

# %% [markdown]
# ### Chest X-Ray

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 3s 124ms/step - loss: 0.5656 - binary_accuracy: 0.7372 - precision: 0.7883 - recall: 0.7923

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:09<00:00, 103.16it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 101.67it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 101.37it/s]
#  32%|███▏      | 319/1000 [00:03<00:06, 102.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-915d70939ad6> in <module>
# ----> 1 explained_images = Image.explain(images, model, IMAGE_SIZE)
#
# c:\Users\danif\PycharmProjects\pneumonia-detection\src\utils\image.py in explain(images, model, image_size)
#      12         for image in images:
#      13             explainer = lime_image.LimeImageExplainer()
# ---> 14             explanation = explainer.explain_instance(image.astype('double'), model.predict, top_labels=5, hide_color=0,
#      15                                                      num_samples=1000)
#      16             image, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=5,
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\lime\lime_image.py in explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     196         top = labels
#     197
# --> 198         data, labels = self.data_labels(image, fudged_image, segments,
#     199                                         classifier_fn, num_samples,
#     200                                         batch_size=batch_size)
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\lime\lime_image.py in data_labels(self, image, fudged_image, segments, classifier_fn, num_samples, batch_size)
#     259             imgs.append(temp)
#     260             if len(imgs) == batch_size:
# --> 261                 preds = classifier_fn(np.array(imgs))
#     262                 labels.extend(preds)
#     263                 imgs = []
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1645       callbacks.on_predict_end()
#    1646     all_outputs = nest.map_structure_up_to(batch_outputs, concat, outputs)
# -> 1647     return tf_utils.to_numpy_or_python_type(all_outputs)
#    1648
#    1649   def reset_metrics(self):
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in to_numpy_or_python_type(tensors)
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#     513
# --> 514   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     515
#     516
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     508   def _to_single_numpy_or_python_type(t):
#     509     if isinstance(t, ops.Tensor):
# --> 510       x = t.numpy()
#     511       return x.item() if np.ndim(x) == 0 else x
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1069     """
#    1070     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1071     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1072     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1073
#
# ~\anaconda3\envs\tf_2.4\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1035   def _numpy(self):
#    1036     try:
# -> 1037       return self._numpy_internal()
#    1038     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1039       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df(). diagnosis.to_numpy())
