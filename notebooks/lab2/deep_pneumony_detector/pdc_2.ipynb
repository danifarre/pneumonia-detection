# %% [markdown]
# # Imports

# %%
import datetime
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = (256, 256)

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(pdc)
# Out:
# Train:
#  - Normal: 4643
#  - Pneumonia: 4536
# Test:
#  - Normal: 1558
#  - Pneumonia: 1476
# Val:
#  - Normal: 16
#  - Pneumonia: 4

# %%
x_train, y_train, _ = pdc.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = pdc.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.Conv2D(filters, 3, activation=tf.keras.layers.LeakyReLU(), padding='same'),
        tf.keras.layers.Conv2D(filters, 3, activation=tf.keras.layers.LeakyReLU(), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])

    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation=tf.keras.layers.LeakyReLU()),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])

    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),

        tf.keras.layers.Conv2D(16, 3, activation=tf.keras.layers.LeakyReLU(), padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation=tf.keras.layers.LeakyReLU(), padding='same'),
        tf.keras.layers.MaxPool2D(),

        conv_block(32),
        conv_block(64),
        conv_block(128),
        conv_block(128),

        tf.keras.layers.Flatten(),
        dense_block(516, 0.2),
        dense_block(256, 0.2),
        dense_block(128, 0.2),
        dense_block(64, 0.2),

        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# sequential (Sequential)      (None, 64, 64, 32)        14016
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 32, 32, 64)        55680
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 16, 16, 128)       221952
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 8, 8, 128)         295680
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 516)               4229652
# _________________________________________________________________
# sequential_5 (Sequential)    (None, 256)               133376
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 128)               33408
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 64)                8512
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,995,109
# Trainable params: 4,992,477
# Non-trainable params: 2,632
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=50)
# Out:
# Epoch 1/50
# 574/574 [==============================] - 93s 149ms/step - loss: 0.7341 - binary_accuracy: 0.6035 - precision: 0.5983 - recall: 0.6039 - val_loss: 0.9423 - val_binary_accuracy: 0.5500 - val_precision: 0.3077 - val_recall: 1.0000
# Epoch 2/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.6334 - binary_accuracy: 0.6658 - precision: 0.6670 - recall: 0.6501 - val_loss: 0.5327 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.6105 - binary_accuracy: 0.6765 - precision: 0.6776 - recall: 0.6526 - val_loss: 0.3536 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000
# Epoch 4/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.6081 - binary_accuracy: 0.6782 - precision: 0.6701 - recall: 0.6829 - val_loss: 0.4635 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 5/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5989 - binary_accuracy: 0.6924 - precision: 0.6841 - recall: 0.6797 - val_loss: 0.5371 - val_binary_accuracy: 0.6500 - val_precision: 0.3333 - val_recall: 0.7500
# Epoch 6/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5935 - binary_accuracy: 0.6923 - precision: 0.6974 - recall: 0.6799 - val_loss: 0.6381 - val_binary_accuracy: 0.6000 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 7/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5824 - binary_accuracy: 0.6998 - precision: 0.7057 - recall: 0.6872 - val_loss: 0.4730 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 8/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5892 - binary_accuracy: 0.6942 - precision: 0.6872 - recall: 0.6672 - val_loss: 0.3413 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5879 - binary_accuracy: 0.6977 - precision: 0.6955 - recall: 0.6797 - val_loss: 0.3369 - val_binary_accuracy: 0.8500 - val_precision: 1.0000 - val_recall: 0.2500
# Epoch 10/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5791 - binary_accuracy: 0.7013 - precision: 0.7098 - recall: 0.6827 - val_loss: 0.3888 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 11/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5758 - binary_accuracy: 0.7041 - precision: 0.7061 - recall: 0.6821 - val_loss: 0.4399 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 12/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5746 - binary_accuracy: 0.7175 - precision: 0.7116 - recall: 0.7322 - val_loss: 0.3100 - val_binary_accuracy: 0.8500 - val_precision: 1.0000 - val_recall: 0.2500
# Epoch 13/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5699 - binary_accuracy: 0.7126 - precision: 0.7115 - recall: 0.7129 - val_loss: 0.6486 - val_binary_accuracy: 0.6500 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 14/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5708 - binary_accuracy: 0.7125 - precision: 0.7062 - recall: 0.7073 - val_loss: 0.4491 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 15/50
# 574/574 [==============================] - 84s 146ms/step - loss: 0.5767 - binary_accuracy: 0.6954 - precision: 0.6863 - recall: 0.7003 - val_loss: 0.3438 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 16/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.5689 - binary_accuracy: 0.7070 - precision: 0.6962 - recall: 0.7226 - val_loss: 0.4077 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch
50
# 574/574 [==============================] - 85s 147ms/step - loss: 0.5307 - binary_accuracy: 0.7428 - precision: 0.7377 - recall: 0.7349 - val_loss: 1.2198 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/50
# 574/574 [==============================] - 85s 147ms/step - loss: 0.5960 - binary_accuracy: 0.6882 - precision: 0.6880 - recall: 0.6810 - val_loss: 0.4280 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 43/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.5600 - binary_accuracy: 0.7179 - precision: 0.7110 - recall: 0.7143 - val_loss: 0.2588 - val_binary_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 44/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.5527 - binary_accuracy: 0.7285 - precision: 0.7208 - recall: 0.7273 - val_loss: 0.6739 - val_binary_accuracy: 0.6000 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 45/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.5407 - binary_accuracy: 0.7318 - precision: 0.7307 - recall: 0.7329 - val_loss: 0.3825 - val_binary_accuracy: 0.8500 - val_precision: 0.6667 - val_recall: 0.5000
# Epoch 46/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.5371 - binary_accuracy: 0.7368 - precision: 0.7373 - recall: 0.7322 - val_loss: 0.5530 - val_binary_accuracy: 0.7500 - val_precision: 0.4444 - val_recall: 1.0000
# Epoch 47/50
# 574/574 [==============================] - 84s 147ms/step - loss: 0.5268 - binary_accuracy: 0.7449 - precision: 0.7403 - recall: 0.7453 - val_loss: 0.2907 - val_binary_accuracy: 0.9000 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 48/50
# 574/574 [==============================] - 85s 147ms/step - loss: 0.5230 - binary_accuracy: 0.7380 - precision: 0.7315 - recall: 0.7417 - val_loss: 0.3382 - val_binary_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.5000
# Epoch 49/50
# 574/574 [==============================] - 85s 148ms/step - loss: 0.5304 - binary_accuracy: 0.7456 - precision: 0.7431 - recall: 0.7419 - val_loss: 0.4175 - val_binary_accuracy: 0.8500 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 50/50
# 574/574 [==============================] - 85s 147ms/step - loss: 0.5293 - binary_accuracy: 0.7382 - precision: 0.7384 - recall: 0.7464 - val_loss: 0.4053 - val_binary_accuracy: 0.8500 - val_precision: 0.6000 - val_recall: 0.7500

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %%
time = str(datetime.datetime.now().strftime("%d%m%Y%H%M%S"))

model_json = model.to_json()
with open("models/" + "pdc_" + time + ".json", "w") as json_file:
    json_file.write(model_json)

model.save_weights("models/" + "pdc_" + time + ".h5")
print("pdc_" + time)
# Out:
# pdc_07022022192335

# %% [markdown]
# # Evaluating the model

# %% [markdown]
# ### Pneumonia Detection Challenge

# %%
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 3s 29ms/step - loss: 0.4933 - binary_accuracy: 0.7693 - precision: 0.7803 - recall: 0.7317

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 149.93it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 125.61it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 129.65it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 133.45it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 126.53it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 112.63it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 132.41it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 134.27it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 128.05it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 134.44it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df().diagnosis.to_numpy())

# %% [markdown]
# ### Chest X-Ray

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 1s 26ms/step - loss: 0.4337 - binary_accuracy: 0.8718 - precision: 0.8799 - recall: 0.9205

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 137.96it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 119.73it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 117.25it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 122.73it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 124.42it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 124.96it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 130.36it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 126.73it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 124.07it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 119.76it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df(). diagnosis.to_numpy())
