# %% [markdown]
# # Imports

# %%
import datetime
from configuration.paths import *

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

from src.datasets.pneumonia_detection_challenge import PneumoniaDetectionChallenge
from src.datasets.chest_xray import ChestXRay
from src.utils.schemes import Scheme
from src.utils.image import Image

# %% [markdown]
# # Dataset loading for training

# %%
IMAGE_SIZE = [256, 256]

# %%
cx = ChestXRay(DATASET_CHEST_XRAY_PATH, IMAGE_SIZE)

# %%
Scheme.dataset_info(cx)
# Out:
# Train:
#  - Normal: 1341
#  - Pneumonia: 1938
# Test:
#  - Normal: 234
#  - Pneumonia: 390
# Val:
#  - Normal: 8
#  - Pneumonia: 8

# %%
x_train, y_train, _ = cx.load_train_data()
x_train = x_train / 255.0

x_val, y_val, _ = cx.load_val_data()
x_val = x_val / 255.0

# %%
Scheme.labeled_images(x_train, y_train)

# %% [markdown]
# # Mdel definition

# %%
vgg = VGG16(input_shape = IMAGE_SIZE + [3],
        weights = 'imagenet',
        include_top=False)

for layer in vgg.layers:
  layer.trainable = False

# %%
x = tf.keras.layers.Flatten()(vgg.output)
x = tf.keras.layers.Dense(1000, activation='relu')(x)
prediction = tf.keras.layers.Dense(1, activation='sigmoid')(x)

# %%
model = tf.keras.models.Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              32769000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 47,484,689
# Trainable params: 32,770,001
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['binary_accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')])

# %% [markdown]
# # Model training

# %%
aug = ImageDataGenerator(rotation_range=45, zoom_range=0.3,
						width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
						vertical_flip=True, horizontal_flip=True, fill_mode="nearest")

history = model.fit(aug.flow(x_train, y_train, batch_size=16),
					validation_data=(x_val, y_val),
					epochs=15)
# Out:
# Epoch 1/15
# 205/205 [==============================] - 37s 159ms/step - loss: 1.4944 - binary_accuracy: 0.7554 - precision: 0.7803 - recall: 0.7874 - val_loss: 0.7796 - val_binary_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 2/15
# 205/205 [==============================] - 31s 149ms/step - loss: 0.3673 - binary_accuracy: 0.8719 - precision: 0.8982 - recall: 0.8849 - val_loss: 0.3469 - val_binary_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 3/15
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2499 - binary_accuracy: 0.9012 - precision: 0.9310 - recall: 0.9000 - val_loss: 0.2022 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 4/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2356 - binary_accuracy: 0.9082 - precision: 0.9379 - recall: 0.9074 - val_loss: 0.4149 - val_binary_accuracy: 0.8125 - val_precision: 1.0000 - val_recall: 0.6250
# Epoch 5/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.2390 - binary_accuracy: 0.9064 - precision: 0.9355 - recall: 0.9065 - val_loss: 0.1554 - val_binary_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 6/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1672 - binary_accuracy: 0.9392 - precision: 0.9558 - recall: 0.9403 - val_loss: 0.3879 - val_binary_accuracy: 0.8125 - val_precision: 1.0000 - val_recall: 0.6250
# Epoch 7/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1856 - binary_accuracy: 0.9300 - precision: 0.9534 - recall: 0.9261 - val_loss: 0.3958 - val_binary_accuracy: 0.8125 - val_precision: 1.0000 - val_recall: 0.6250
# Epoch 8/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1891 - binary_accuracy: 0.9245 - precision: 0.9513 - recall: 0.9237 - val_loss: 0.4770 - val_binary_accuracy: 0.7500 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 9/15
# 205/205 [==============================] - 30s 147ms/step - loss: 0.2105 - binary_accuracy: 0.9234 - precision: 0.9515 - recall: 0.9195 - val_loss: 0.2370 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 10/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1823 - binary_accuracy: 0.9296 - precision: 0.9477 - recall: 0.9322 - val_loss: 0.5177 - val_binary_accuracy: 0.7500 - val_precision: 1.0000 - val_recall: 0.5000
# Epoch 11/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1907 - binary_accuracy: 0.9294 - precision: 0.9470 - recall: 0.9338 - val_loss: 0.3363 - val_binary_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 12/15
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1768 - binary_accuracy: 0.9320 - precision: 0.9494 - recall: 0.9343 - val_loss: 0.3552 - val_binary_accuracy: 0.8125 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 13/15
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1707 - binary_accuracy: 0.9397 - precision: 0.9589 - recall: 0.9399 - val_loss: 0.1910 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 14/15
# 205/205 [==============================] - 30s 146ms/step - loss: 0.1657 - binary_accuracy: 0.9329 - precision: 0.9487 - recall: 0.9377 - val_loss: 0.1777 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 15/15
# 205/205 [==============================] - 30s 147ms/step - loss: 0.1391 - binary_accuracy: 0.9459 - precision: 0.9544 - recall: 0.9527 - val_loss: 0.2103 - val_binary_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750

# %%
Scheme.training_graphs(history)

# %%
del x_train
del y_train

# %% [markdown]
# # Evaluating the model

# %% [markdown]
# ### Chest X-Ray

# %%
x_test, y_test, images = cx.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 6s 82ms/step - loss: 0.2184 - binary_accuracy: 0.9135 - precision: 0.9516 - recall: 0.9077

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [9, 11, 12, 13, 16, 1, 2, 3, 5, 8]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:10<00:00, 94.89it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 110.62it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 108.95it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 109.13it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 109.50it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 109.94it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 113.85it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 111.81it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 111.30it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 108.79it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, cx.get_test_df().diagnosis.to_numpy())

# %% [markdown]
# ### Pneumonia Detection Challenge

# %%
pdc = PneumoniaDetectionChallenge(DATASET_PNEUMONIA_DETECTION_CHALLENGE_PATH, IMAGE_SIZE)
x_test, y_test, images = pdc.load_test_data()
x_test = x_test / 255.0

# %%
test_loss, test_accuracy, _, _ = model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 12s 125ms/step - loss: 1.3635 - binary_accuracy: 0.6496 - precision: 0.5936 - recall: 0.8875s - loss: 1.0926 - binary_accuracy: 0.7

# %%
predictions = model.predict(x_test)
predictions_rounded = np.round(predictions).astype(int)

# %%
images_index = [103, 117, 156, 353, 465, 1615, 1707, 1875, 1951, 2150]
images = [x_test[img] for img in images_index]
labels = [y_test[img] for img in images_index]
predicted_images = [predictions_rounded[img][0] for img in images_index]

# %% [markdown]
# Before explaining the images

# %%
Scheme.labeled_images(images, labels)

# %% [markdown]
# Explain the images

# %%
explained_images = Image.explain(images, model, IMAGE_SIZE)
# Out:
# 100%|██████████| 1000/1000 [00:08<00:00, 112.08it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 111.99it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 109.48it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 113.31it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 112.09it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 111.24it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 114.73it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 113.18it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 111.17it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 113.41it/s]

# %% [markdown]
# Green regions -> Supporting the predicted label
#
# Red regions -> Against the predicted label

# %%
Scheme.labeled_images(explained_images, predicted_images)

# %%
Scheme.confusion_matrix(predictions_rounded, pdc.get_test_df(). diagnosis.to_numpy())
